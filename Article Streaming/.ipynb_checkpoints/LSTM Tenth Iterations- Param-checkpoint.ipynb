# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    901
# sma      901
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:2].values
valid_set = data2.iloc[650:, 1:2].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 200, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 32)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 11s 304ms/step - loss: 0.1345 - val_loss: 0.0488
#
# Epoch 00001: val_loss improved from inf to 0.04880, saving model to weights.h5
# Epoch 2/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0188 - val_loss: 0.0452
#
# Epoch 00002: val_loss improved from 0.04880 to 0.04516, saving model to weights.h5
# Epoch 3/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0165 - val_loss: 0.0406
#
# Epoch 00003: val_loss improved from 0.04516 to 0.04056, saving model to weights.h5
# Epoch 4/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0139 - val_loss: 0.0343
#
# Epoch 00004: val_loss improved from 0.04056 to 0.03432, saving model to weights.h5
# Epoch 5/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0155 - val_loss: 0.0316
#
# Epoch 00005: val_loss improved from 0.03432 to 0.03162, saving model to weights.h5
# Epoch 6/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0145 - val_loss: 0.0304
#
# Epoch 00006: val_loss improved from 0.03162 to 0.03036, saving model to weights.h5
# Epoch 7/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0120 - val_loss: 0.0276
#
# Epoch 00007: val_loss improved from 0.03036 to 0.02760, saving model to weights.h5
# Epoch 8/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0153 - val_loss: 0.0355
#
# Epoch 00008: val_loss did not improve from 0.02760
# Epoch 9/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0138 - val_loss: 0.0249
#
# Epoch 00009: val_loss improved from 0.02760 to 0.02493, saving model to weights.h5
# Epoch 10/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0127 - val_loss: 0.0246
#
# Epoch 00010: val_loss improved from 0.02493 to 0.02461, saving model to weights.h5
# Epoch 11/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0099 - val_loss: 0.0227
#
# Epoch 00011: val_loss improved from 0.02461 to 0.02267, saving model to weights.h5
# Epoch 12/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0098 - val_loss: 0.0255
#
# Epoch 00012: val_loss did not improve from 0.02267
# Epoch 13/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0106 - val_loss: 0.0203
#
# Epoch 00013: val_loss improved from 0.02267 to 0.02028, saving model to weights.h5
# Epoch 14/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0089 - val_loss: 0.0204
#
# Epoch 00014: val_loss did not improve from 0.02028
# Epoch 15/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0082 - val_loss: 0.0188
#
# Epoch 00015: val_loss improved from 0.02028 to 0.01878, saving model to weights.h5
# Epoch 16/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0082 - val_loss: 0.0193
#
# Epoch 00016: val_loss did not improve from 0.01878
# Epoch 17/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0072 - val_loss: 0.0197
#
# Epoch 00017: val_loss did not improve from 0.01878
# Epoch 18/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0071 - val_loss: 0.0172
#
# Epoch 00018: val_loss improved from 0.01878 to 0.01724, saving model to weights.h5
# Epoch 19/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0075 - val_loss: 0.0170
#
# Epoch 00019: val_loss improved from 0.01724 to 0.01697, saving model to weights.h5
# Epoch 20/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0074 - val_loss: 0.0158
#
# Epoch 00020: val_loss improved from 0.01697 to 0.01576, saving model to weights.h5
# Epoch 21/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0078 - val_loss: 0.0157
#
# Epoch 00021: val_loss improved from 0.01576 to 0.01568, saving model to weights.h5
# Epoch 22/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0075 - val_loss: 0.0152
#
# Epoch 00022: val_loss improved from 0.01568 to 0.01521, saving model to weights.h5
# Epoch 23/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0070 - val_loss: 0.0149
#
# Epoch 00023: val_loss improved from 0.01521 to 0.01489, saving model to weights.h5
# Epoch 24/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0062 - val_loss: 0.0147
#
# Epoch 00024: val_loss improved from 0.01489 to 0.01470, saving model to weights.h5
# Epoch 25/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0058 - val_loss: 0.0142
#
# Epoch 00025: val_loss improved from 0.01470 to 0.01418, saving model to weights.h5
# Epoch 26/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0069 - val_loss: 0.0150
#
# Epoch 00026: val_loss did not improve from 0.01418
# Epoch 27/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0051 - val_loss: 0.0137
#
# Epoch 00027: val_loss improved from 0.01418 to 0.01369, saving model to weights.h5
# Epoch 28/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0065 - val_loss: 0.0160
#
# Epoch 00028: val_loss did not improve from 0.01369
# Epoch 29/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0057 - val_loss: 0.0134
#
# Epoch 00029: val_loss improved from 0.01369 to 0.01336, saving model to weights.h5
# Epoch 30/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0054 - val_loss: 0.0126
#
# Epoch 00030: val_loss improved from 0.01336 to 0.01260, saving model to weights.h5
# Epoch 31/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0068 - val_loss: 0.0130
#
# Epoch 00031: val_loss did not improve from 0.01260
# Epoch 32/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0056 - val_loss: 0.0126
#
# Epoch 00032: val_loss did not improve from 0.01260
# Epoch 33/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0064 - val_loss: 0.0125
#
# Epoch 00033: val_loss improved from 0.01260 to 0.01247, saving model to weights.h5
# Epoch 34/200
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0059 - val_loss: 0.0125
#
# Epoch 00034: val_loss did not improve from 0.01247
# Epoch 35/200
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0072 - val_loss: 0.0176
#
# Epoch 00035: val_loss did not improve from 0.01247
# Epoch 36/200
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0064 - val_loss: 0.0123
#
# Epoch 00036: val_loss improved from 0.01247 to 0.01230, saving model to weights.h5
# Epoch 37/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0053 - val_loss: 0.0121
#
# Epoch 00037: val_loss improved from 0.01230 to 0.01206, saving model to weights.h5
# Epoch 38/200
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0065 - val_loss: 0.0140
#
# Epoch 00038: val_loss did not improve from 0.01206
# Epoch 39/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0056 - val_loss: 0.0119
#
# Epoch 00039: val_loss improved from 0.01206 to 0.01187, saving model to weights.h5
# Epoch 40/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0050 - val_loss: 0.0118
#
# Epoch 00040: val_loss improved from 0.01187 to 0.01181, saving model to weights.h5
# Epoch 41/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0052 - val_loss: 0.0136
#
# Epoch 00041: val_loss did not improve from 0.01181
# Epoch 42/200
# 19/19 [==============================] - 1s 71ms/step - loss: 0.0051 - val_loss: 0.0136
#
# Epoch 00042: val_loss did not improve from 0.01181
# Epoch 43/200
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0049 - val_loss: 0.0114
#
# Epoch 00043: val_loss improved from 0.01181 to 0.01143, saving model to weights.h5
# Epoch 44/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0057 - val_loss: 0.0129
#
# Epoch 00044: val_loss did not improve from 0.01143
# Epoch 45/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0054 - val_loss: 0.0112
#
# Epoch 00045: val_loss improved from 0.01143 to 0.01117, saving model to weights.h5
# Epoch 46/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0053 - val_loss: 0.0110
#
# Epoch 00046: val_loss improved from 0.01117 to 0.01100, saving model to weights.h5
# Epoch 47/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0056 - val_loss: 0.0114
#
# Epoch 00047: val_loss did not improve from 0.01100
# Epoch 48/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0053 - val_loss: 0.0107
#
# Epoch 00048: val_loss improved from 0.01100 to 0.01065, saving model to weights.h5
# Epoch 49/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0050 - val_loss: 0.0107
#
# Epoch 00049: val_loss did not improve from 0.01065
# Epoch 50/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0046 - val_loss: 0.0109
#
# Epoch 00050: val_loss did not improve from 0.01065
# Epoch 51/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0047 - val_loss: 0.0115
#
# Epoch 00051: val_loss did not improve from 0.01065
# Epoch 52/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0046 - val_loss: 0.0102
#
# Epoch 00052: val_loss improved from 0.01065 to 0.01020, saving model to weights.h5
# Epoch 53/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0041 - val_loss: 0.0100
#
# Epoch 00053: val_loss improved from 0.01020 to 0.01002, saving model to weights.h5
# Epoch 54/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0050 - val_loss: 0.0110
#
# Epoch 00054: val_loss did not improve from 0.01002
# Epoch 55/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0046 - val_loss: 0.0101
#
# Epoch 00055: val_loss did not improve from 0.01002
# Epoch 56/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0047 - val_loss: 0.0098
#
# Epoch 00056: val_loss improved from 0.01002 to 0.00983, saving model to weights.h5
# Epoch 57/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0047 - val_loss: 0.0099
#
# Epoch 00057: val_loss did not improve from 0.00983
# Epoch 58/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0045 - val_loss: 0.0101
#
# Epoch 00058: val_loss did not improve from 0.00983
# Epoch 59/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0042 - val_loss: 0.0096
#
# Epoch 00059: val_loss improved from 0.00983 to 0.00960, saving model to weights.h5
# Epoch 60/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0043 - val_loss: 0.0100
#
# Epoch 00060: val_loss did not improve from 0.00960
# Epoch 61/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0047 - val_loss: 0.0100
#
# Epoch 00061: val_loss did not improve from 0.00960
# Epoch 62/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0042 - val_loss: 0.0106
#
# Epoch 00062: val_loss did not improve from 0.00960
# Epoch 63/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0053 - val_loss: 0.0098
#
# Epoch 00063: val_loss did not improve from 0.00960
# Epoch 64/200
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0043 - val_loss: 0.0095
#
# Epoch 00064: val_loss improved from 0.00960 to 0.00945, saving model to weights.h5
# Epoch 65/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0044 - val_loss: 0.0092
#
# Epoch 00065: val_loss improved from 0.00945 to 0.00923, saving model to weights.h5
# Epoch 66/200
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0043 - val_loss: 0.0090
#
# Epoch 00066: val_loss improved from 0.00923 to 0.00903, saving model to weights.h5
# Epoch 67/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0040 - val_loss: 0.0097
#
# Epoch 00067: val_loss did not improve from 0.00903
# Epoch 68/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0046 - val_loss: 0.0103
#
# Epoch 00068: val_loss did not improve from 0.00903
# Epoch 69/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0043 - val_loss: 0.0093
#
# Epoch 00069: val_loss did not improve from 0.00903
# Epoch 70/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0044 - val_loss: 0.0086
#
# Epoch 00070: val_loss improved from 0.00903 to 0.00858, saving model to weights.h5
# Epoch 71/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0041 - val_loss: 0.0089
#
# Epoch 00071: val_loss did not improve from 0.00858
# Epoch 72/200
# 11/19 [================>.............] - ETA: 0s - loss: 0.0042

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:2].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 686.0865344915114

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-16-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
