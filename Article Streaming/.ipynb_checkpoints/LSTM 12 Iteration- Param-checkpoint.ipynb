# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    879
# sma      879
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:3].values
valid_set = data2.iloc[650:, 1:3].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 100, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 256)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 11s 2s/step - loss: 0.2337 - val_loss: 0.0760
#
# Epoch 00001: val_loss improved from inf to 0.07602, saving model to weights.h5
# Epoch 2/100
# 3/3 [==============================] - 1s 218ms/step - loss: 0.0628 - val_loss: 0.1292
#
# Epoch 00002: val_loss did not improve from 0.07602
# Epoch 3/100
# 3/3 [==============================] - 1s 233ms/step - loss: 0.0697 - val_loss: 0.0407
#
# Epoch 00003: val_loss improved from 0.07602 to 0.04071, saving model to weights.h5
# Epoch 4/100
# 3/3 [==============================] - 1s 249ms/step - loss: 0.0242 - val_loss: 0.0397
#
# Epoch 00004: val_loss improved from 0.04071 to 0.03970, saving model to weights.h5
# Epoch 5/100
# 3/3 [==============================] - 1s 214ms/step - loss: 0.0377 - val_loss: 0.0356
#
# Epoch 00005: val_loss improved from 0.03970 to 0.03559, saving model to weights.h5
# Epoch 6/100
# 3/3 [==============================] - 1s 223ms/step - loss: 0.0291 - val_loss: 0.0367
#
# Epoch 00006: val_loss did not improve from 0.03559
# Epoch 7/100
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0229 - val_loss: 0.0541
#
# Epoch 00007: val_loss did not improve from 0.03559
# Epoch 8/100
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0289 - val_loss: 0.0422
#
# Epoch 00008: val_loss did not improve from 0.03559
# Epoch 9/100
# 3/3 [==============================] - 1s 278ms/step - loss: 0.0214 - val_loss: 0.0325
#
# Epoch 00009: val_loss improved from 0.03559 to 0.03253, saving model to weights.h5
# Epoch 10/100
# 3/3 [==============================] - 1s 267ms/step - loss: 0.0211 - val_loss: 0.0319
#
# Epoch 00010: val_loss improved from 0.03253 to 0.03189, saving model to weights.h5
# Epoch 11/100
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0216 - val_loss: 0.0354
#
# Epoch 00011: val_loss did not improve from 0.03189
# Epoch 12/100
# 3/3 [==============================] - 2s 625ms/step - loss: 0.0182 - val_loss: 0.0414
#
# Epoch 00012: val_loss did not improve from 0.03189
# Epoch 13/100
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0170 - val_loss: 0.0386
#
# Epoch 00013: val_loss did not improve from 0.03189
# Epoch 14/100
# 3/3 [==============================] - 1s 244ms/step - loss: 0.0160 - val_loss: 0.0349
#
# Epoch 00014: val_loss did not improve from 0.03189
# Epoch 15/100
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0169 - val_loss: 0.0351
#
# Epoch 00015: val_loss did not improve from 0.03189
# Epoch 16/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0157 - val_loss: 0.0389
#
# Epoch 00016: val_loss did not improve from 0.03189
# Epoch 17/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0161 - val_loss: 0.0367
#
# Epoch 00017: val_loss did not improve from 0.03189
# Epoch 18/100
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0152 - val_loss: 0.0346
#
# Epoch 00018: val_loss did not improve from 0.03189
# Epoch 19/100
# 3/3 [==============================] - 2s 701ms/step - loss: 0.0152 - val_loss: 0.0351
#
# Epoch 00019: val_loss did not improve from 0.03189
# Epoch 20/100
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0139 - val_loss: 0.0347
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.03189
# Epoch 21/100
# 3/3 [==============================] - 1s 289ms/step - loss: 0.0149 - val_loss: 0.0343
#
# Epoch 00021: val_loss did not improve from 0.03189
# Epoch 22/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0150 - val_loss: 0.0345
#
# Epoch 00022: val_loss did not improve from 0.03189
# Epoch 23/100
# 3/3 [==============================] - 1s 269ms/step - loss: 0.0141 - val_loss: 0.0346
#
# Epoch 00023: val_loss did not improve from 0.03189
# Epoch 24/100
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0145 - val_loss: 0.0339
#
# Epoch 00024: val_loss did not improve from 0.03189
# Epoch 25/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0138 - val_loss: 0.0346
#
# Epoch 00025: val_loss did not improve from 0.03189
# Epoch 26/100
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0142 - val_loss: 0.0334
#
# Epoch 00026: val_loss did not improve from 0.03189
# Epoch 27/100
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0140 - val_loss: 0.0317
#
# Epoch 00027: val_loss improved from 0.03189 to 0.03175, saving model to weights.h5
# Epoch 28/100
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0133 - val_loss: 0.0310
#
# Epoch 00028: val_loss improved from 0.03175 to 0.03104, saving model to weights.h5
# Epoch 29/100
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0138 - val_loss: 0.0321
#
# Epoch 00029: val_loss did not improve from 0.03104
# Epoch 30/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0132 - val_loss: 0.0329
#
# Epoch 00030: val_loss did not improve from 0.03104
# Epoch 31/100
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0140 - val_loss: 0.0322
#
# Epoch 00031: val_loss did not improve from 0.03104
# Epoch 32/100
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0120 - val_loss: 0.0293
#
# Epoch 00032: val_loss improved from 0.03104 to 0.02930, saving model to weights.h5
# Epoch 33/100
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0131 - val_loss: 0.0283
#
# Epoch 00033: val_loss improved from 0.02930 to 0.02833, saving model to weights.h5
# Epoch 34/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0139 - val_loss: 0.0304
#
# Epoch 00034: val_loss did not improve from 0.02833
# Epoch 35/100
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0128 - val_loss: 0.0320
#
# Epoch 00035: val_loss did not improve from 0.02833
# Epoch 36/100
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0114 - val_loss: 0.0290
#
# Epoch 00036: val_loss did not improve from 0.02833
# Epoch 37/100
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0137 - val_loss: 0.0267
#
# Epoch 00037: val_loss improved from 0.02833 to 0.02668, saving model to weights.h5
# Epoch 38/100
# 3/3 [==============================] - 1s 249ms/step - loss: 0.0126 - val_loss: 0.0281
#
# Epoch 00038: val_loss did not improve from 0.02668
# Epoch 39/100
# 3/3 [==============================] - 1s 244ms/step - loss: 0.0131 - val_loss: 0.0312
#
# Epoch 00039: val_loss did not improve from 0.02668
# Epoch 40/100
# 3/3 [==============================] - 1s 243ms/step - loss: 0.0130 - val_loss: 0.0283
#
# Epoch 00040: val_loss did not improve from 0.02668
# Epoch 41/100
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0120 - val_loss: 0.0263
#
# Epoch 00041: val_loss improved from 0.02668 to 0.02635, saving model to weights.h5
# Epoch 42/100
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0120 - val_loss: 0.0284
#
# Epoch 00042: val_loss did not improve from 0.02635
# Epoch 43/100
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0123 - val_loss: 0.0285
#
# Epoch 00043: val_loss did not improve from 0.02635
# Epoch 44/100
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0135 - val_loss: 0.0252
#
# Epoch 00044: val_loss improved from 0.02635 to 0.02519, saving model to weights.h5
# Epoch 45/100
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0124 - val_loss: 0.0258
#
# Epoch 00045: val_loss did not improve from 0.02519
# Epoch 46/100
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0125 - val_loss: 0.0294
#
# Epoch 00046: val_loss did not improve from 0.02519
# Epoch 47/100
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0126 - val_loss: 0.0268
#
# Epoch 00047: val_loss did not improve from 0.02519
# Epoch 48/100
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0125 - val_loss: 0.0237
#
# Epoch 00048: val_loss improved from 0.02519 to 0.02369, saving model to weights.h5
# Epoch 49/100
# 3/3 [==============================] - 1s 237ms/step - loss: 0.0123 - val_loss: 0.0263
#
# Epoch 00049: val_loss did not improve from 0.02369
# Epoch 50/100
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0119 - val_loss: 0.0258
#
# Epoch 00050: val_loss did not improve from 0.02369
# Epoch 51/100
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0112 - val_loss: 0.0235
# Epoch 00051: val_loss improved from 0.02369 to 0.02355, saving model to weights.h5
# Epoch 52/100
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0120 - val_loss: 0.0265
#
# Epoch 00052: val_loss did not improve from 0.02355
# Epoch 53/100
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0122 - val_loss: 0.0266
#
# Epoch 00053: val_loss did not improve from 0.02355
# Epoch 54/100
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0115 - val_loss: 0.0232
#
# Epoch 00054: val_loss improved from 0.02355 to 0.02322, saving model to weights.h5
# Epoch 55/100
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0124 - val_loss: 0.0249
#
# Epoch 00055: val_loss did not improve from 0.02322
# Epoch 56/100
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0116 - val_loss: 0.0259
#
# Epoch 00056: val_loss did not improve from 0.02322
# Epoch 57/100
# 3/3 [==============================] - 1s 244ms/step - loss: 0.0119 - val_loss: 0.0241
#
# Epoch 00057: val_loss did not improve from 0.02322
# Epoch 58/100
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0102 - val_loss: 0.0224
#
# Epoch 00058: val_loss improved from 0.02322 to 0.02244, saving model to weights.h5
# Epoch 59/100
# 3/3 [==============================] - 1s 289ms/step - loss: 0.0123 - val_loss: 0.0263
#
# Epoch 00059: val_loss did not improve from 0.02244
# Epoch 60/100
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0114 - val_loss: 0.0274
#
# Epoch 00060: val_loss did not improve from 0.02244
# Epoch 61/100
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0110 - val_loss: 0.0232
#
# Epoch 00061: val_loss did not improve from 0.02244
# Epoch 62/100
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0108 - val_loss: 0.0227
#
# Epoch 00062: val_loss did not improve from 0.02244
# Epoch 63/100
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0100 - val_loss: 0.0253
#
# Epoch 00063: val_loss did not improve from 0.02244
# Epoch 64/100
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0119 - val_loss: 0.0239
#
# Epoch 00064: val_loss did not improve from 0.02244
# Epoch 65/100
# 3/3 [==============================] - 1s 286ms/step - loss: 0.0113 - val_loss: 0.0242
#
# Epoch 00065: val_loss did not improve from 0.02244
# Epoch 66/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0110 - val_loss: 0.0242
#
# Epoch 00066: val_loss did not improve from 0.02244
# Epoch 67/100
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0108 - val_loss: 0.0233
#
# Epoch 00067: val_loss did not improve from 0.02244
# Epoch 68/100
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0114 - val_loss: 0.0239
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00068: val_loss did not improve from 0.02244
# Epoch 69/100
# 3/3 [==============================] - 1s 286ms/step - loss: 0.0109 - val_loss: 0.0250
#
# Epoch 00069: val_loss did not improve from 0.02244
# Epoch 70/100
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0109 - val_loss: 0.0243
#
# Epoch 00070: val_loss did not improve from 0.02244
# Epoch 71/100
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0116 - val_loss: 0.0231
#
# Epoch 00071: val_loss did not improve from 0.02244
# Epoch 72/100
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0106 - val_loss: 0.0221
#
# Epoch 00072: val_loss improved from 0.02244 to 0.02209, saving model to weights.h5
# Epoch 73/100
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0100 - val_loss: 0.0229
#
# Epoch 00073: val_loss did not improve from 0.02209
# Epoch 74/100
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0100 - val_loss: 0.0245
#
# Epoch 00074: val_loss did not improve from 0.02209
# Epoch 75/100
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0105 - val_loss: 0.0243
#
# Epoch 00075: val_loss did not improve from 0.02209
# Epoch 76/100
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0113 - val_loss: 0.0226
#
# Epoch 00076: val_loss did not improve from 0.02209
# Epoch 77/100
# 3/3 [==============================] - 1s 244ms/step - loss: 0.0107 - val_loss: 0.0226
#
# Epoch 00077: val_loss did not improve from 0.02209
# Epoch 78/100
# 3/3 [==============================] - 1s 287ms/step - loss: 0.0109 - val_loss: 0.0244
#
# Epoch 00078: val_loss did not improve from 0.02209
# Epoch 79/100
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0106 - val_loss: 0.0255
#
# Epoch 00079: val_loss did not improve from 0.02209
# Epoch 80/100
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0118 - val_loss: 0.0228
#
# Epoch 00080: val_loss did not improve from 0.02209
# Epoch 81/100
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0097 - val_loss: 0.0213
#
# Epoch 00081: val_loss improved from 0.02209 to 0.02125, saving model to weights.h5
# Epoch 82/100
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0115 - val_loss: 0.0222
#
# Epoch 00082: val_loss did not improve from 0.02125
# Epoch 83/100
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0103 - val_loss: 0.0249
#
# Epoch 00083: val_loss did not improve from 0.02125
# Epoch 84/100
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0103 - val_loss: 0.0251
#
# Epoch 00084: val_loss did not improve from 0.02125
# Epoch 85/100
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0105 - val_loss: 0.0235
#
# Epoch 00085: val_loss did not improve from 0.02125
# Epoch 86/100
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0105 - val_loss: 0.0220
#
# Epoch 00086: val_loss did not improve from 0.02125
# Epoch 87/100
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0112 - val_loss: 0.0220
#
# Epoch 00087: val_loss did not improve from 0.02125
# Epoch 88/100
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0111 - val_loss: 0.0235
#
# Epoch 00088: val_loss did not improve from 0.02125
# Epoch 89/100
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0105 - val_loss: 0.0246
#
# Epoch 00089: val_loss did not improve from 0.02125
# Epoch 90/100
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0107 - val_loss: 0.0222
#
# Epoch 00090: val_loss did not improve from 0.02125
# Epoch 91/100
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0103 - val_loss: 0.0218
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00091: val_loss did not improve from 0.02125
# Epoch 92/100
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0099 - val_loss: 0.0222
#
# Epoch 00092: val_loss did not improve from 0.02125
# Epoch 93/100
# 3/3 [==============================] - 1s 267ms/step - loss: 0.0099 - val_loss: 0.0230
#
# Epoch 00093: val_loss did not improve from 0.02125
# Epoch 94/100
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0100 - val_loss: 0.0240
#
# Epoch 00094: val_loss did not improve from 0.02125
# Epoch 95/100
# 3/3 [==============================] - 1s 271ms/step - loss: 0.0105 - val_loss: 0.0243
#
# Epoch 00095: val_loss did not improve from 0.02125
# Epoch 96/100
# 3/3 [==============================] - 1s 283ms/step - loss: 0.0111 - val_loss: 0.0233
#
# Epoch 00096: val_loss did not improve from 0.02125
# Epoch 97/100
# 3/3 [==============================] - 1s 267ms/step - loss: 0.0098 - val_loss: 0.0224
#
# Epoch 00097: val_loss did not improve from 0.02125
# Epoch 98/100
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0106 - val_loss: 0.0223
#
# Epoch 00098: val_loss did not improve from 0.02125
# Epoch 99/100
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0106 - val_loss: 0.0222
#
# Epoch 00099: val_loss did not improve from 0.02125
# Epoch 100/100
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0110 - val_loss: 0.0224
#
# Epoch 00100: val_loss did not improve from 0.02125

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:3].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 811.00438653352

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-15-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
