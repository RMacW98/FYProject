# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    900
# sma      900
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:2].values
valid_set = data2.iloc[650:, 1:2].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.75))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 150, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 256)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 12s 3s/step - loss: 0.2462 - val_loss: 0.1819
#
# Epoch 00001: val_loss improved from inf to 0.18192, saving model to weights.h5
# Epoch 2/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.1413 - val_loss: 0.0504
#
# Epoch 00002: val_loss improved from 0.18192 to 0.05043, saving model to weights.h5
# Epoch 3/150
# 3/3 [==============================] - 1s 224ms/step - loss: 0.0604 - val_loss: 0.0694
#
# Epoch 00003: val_loss did not improve from 0.05043
# Epoch 4/150
# 3/3 [==============================] - 1s 212ms/step - loss: 0.0779 - val_loss: 0.0476
#
# Epoch 00004: val_loss improved from 0.05043 to 0.04763, saving model to weights.h5
# Epoch 5/150
# 3/3 [==============================] - 1s 210ms/step - loss: 0.0490 - val_loss: 0.0675
#
# Epoch 00005: val_loss did not improve from 0.04763
# Epoch 6/150
# 3/3 [==============================] - 1s 227ms/step - loss: 0.0589 - val_loss: 0.0566
#
# Epoch 00006: val_loss did not improve from 0.04763
# Epoch 7/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.0537 - val_loss: 0.0395
#
# Epoch 00007: val_loss improved from 0.04763 to 0.03950, saving model to weights.h5
# Epoch 8/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.0433 - val_loss: 0.0443
#
# Epoch 00008: val_loss did not improve from 0.03950
# Epoch 9/150
# 3/3 [==============================] - 1s 222ms/step - loss: 0.0491 - val_loss: 0.0384
#
# Epoch 00009: val_loss improved from 0.03950 to 0.03843, saving model to weights.h5
# Epoch 10/150
# 3/3 [==============================] - 1s 205ms/step - loss: 0.0403 - val_loss: 0.0437
#
# Epoch 00010: val_loss did not improve from 0.03843
# Epoch 11/150
# 3/3 [==============================] - 1s 223ms/step - loss: 0.0480 - val_loss: 0.0468
#
# Epoch 00011: val_loss did not improve from 0.03843
# Epoch 12/150
# 3/3 [==============================] - 1s 219ms/step - loss: 0.0448 - val_loss: 0.0398
#
# Epoch 00012: val_loss did not improve from 0.03843
# Epoch 13/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.0379 - val_loss: 0.0373
#
# Epoch 00013: val_loss improved from 0.03843 to 0.03734, saving model to weights.h5
# Epoch 14/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.0387 - val_loss: 0.0372
#
# Epoch 00014: val_loss improved from 0.03734 to 0.03722, saving model to weights.h5
# Epoch 15/150
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0435 - val_loss: 0.0389
#
# Epoch 00015: val_loss did not improve from 0.03722
# Epoch 16/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.0345 - val_loss: 0.0405
#
# Epoch 00016: val_loss did not improve from 0.03722
# Epoch 17/150
# 3/3 [==============================] - 1s 205ms/step - loss: 0.0396 - val_loss: 0.0374
#
# Epoch 00017: val_loss did not improve from 0.03722
# Epoch 18/150
# 3/3 [==============================] - 1s 216ms/step - loss: 0.0340 - val_loss: 0.0396
#
# Epoch 00018: val_loss did not improve from 0.03722
# Epoch 19/150
# 3/3 [==============================] - 1s 210ms/step - loss: 0.0342 - val_loss: 0.0375
#
# Epoch 00019: val_loss did not improve from 0.03722
# Epoch 20/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0326 - val_loss: 0.0390
#
# Epoch 00020: val_loss did not improve from 0.03722
# Epoch 21/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0319 - val_loss: 0.0381
#
# Epoch 00021: val_loss did not improve from 0.03722
# Epoch 22/150
# 3/3 [==============================] - 1s 222ms/step - loss: 0.0276 - val_loss: 0.0373
#
# Epoch 00022: val_loss did not improve from 0.03722
# Epoch 23/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0299 - val_loss: 0.0372
#
# Epoch 00023: val_loss improved from 0.03722 to 0.03717, saving model to weights.h5
# Epoch 24/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0305 - val_loss: 0.0366
#
# Epoch 00024: val_loss improved from 0.03717 to 0.03660, saving model to weights.h5
# Epoch 25/150
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0316 - val_loss: 0.0363
#
# Epoch 00025: val_loss improved from 0.03660 to 0.03634, saving model to weights.h5
# Epoch 26/150
# 3/3 [==============================] - 1s 229ms/step - loss: 0.0304 - val_loss: 0.0358
#
# Epoch 00026: val_loss improved from 0.03634 to 0.03578, saving model to weights.h5
# Epoch 27/150
# 3/3 [==============================] - 1s 226ms/step - loss: 0.0342 - val_loss: 0.0361
#
# Epoch 00027: val_loss did not improve from 0.03578
# Epoch 28/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0288 - val_loss: 0.0353
#
# Epoch 00028: val_loss improved from 0.03578 to 0.03529, saving model to weights.h5
# Epoch 29/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0284 - val_loss: 0.0347
#
# Epoch 00029: val_loss improved from 0.03529 to 0.03475, saving model to weights.h5
# Epoch 30/150
# 3/3 [==============================] - 1s 235ms/step - loss: 0.0306 - val_loss: 0.0343
#
# Epoch 00030: val_loss improved from 0.03475 to 0.03433, saving model to weights.h5
# Epoch 31/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0266 - val_loss: 0.0343
#
# Epoch 00031: val_loss improved from 0.03433 to 0.03428, saving model to weights.h5
# Epoch 32/150
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0279 - val_loss: 0.0341
#
# Epoch 00032: val_loss improved from 0.03428 to 0.03411, saving model to weights.h5
# Epoch 33/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0262 - val_loss: 0.0338
#
# Epoch 00033: val_loss improved from 0.03411 to 0.03379, saving model to weights.h5
# Epoch 34/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0273 - val_loss: 0.0345
#
# Epoch 00034: val_loss did not improve from 0.03379
# Epoch 35/150
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0270 - val_loss: 0.0339
#
# Epoch 00035: val_loss did not improve from 0.03379
# Epoch 36/150
# 3/3 [==============================] - 1s 243ms/step - loss: 0.0275 - val_loss: 0.0337
#
# Epoch 00036: val_loss improved from 0.03379 to 0.03372, saving model to weights.h5
# Epoch 37/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0259 - val_loss: 0.0333
#
# Epoch 00037: val_loss improved from 0.03372 to 0.03331, saving model to weights.h5
# Epoch 38/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0278 - val_loss: 0.0354
#
# Epoch 00038: val_loss did not improve from 0.03331
# Epoch 39/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0292 - val_loss: 0.0328
#
# Epoch 00039: val_loss improved from 0.03331 to 0.03280, saving model to weights.h5
# Epoch 40/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0263 - val_loss: 0.0330
#
# Epoch 00040: val_loss did not improve from 0.03280
# Epoch 41/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0260 - val_loss: 0.0325
#
# Epoch 00041: val_loss improved from 0.03280 to 0.03252, saving model to weights.h5
# Epoch 42/150
# 3/3 [==============================] - 1s 237ms/step - loss: 0.0252 - val_loss: 0.0332
#
# Epoch 00042: val_loss did not improve from 0.03252
# Epoch 43/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0231 - val_loss: 0.0320
#
# Epoch 00043: val_loss improved from 0.03252 to 0.03197, saving model to weights.h5
# Epoch 44/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0233 - val_loss: 0.0317
#
# Epoch 00044: val_loss improved from 0.03197 to 0.03175, saving model to weights.h5
# Epoch 45/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0240 - val_loss: 0.0318
#
# Epoch 00045: val_loss did not improve from 0.03175
# Epoch 46/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0270 - val_loss: 0.0313
#
# Epoch 00046: val_loss improved from 0.03175 to 0.03128, saving model to weights.h5
# Epoch 47/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0230 - val_loss: 0.0317
#
# Epoch 00047: val_loss did not improve from 0.03128
# Epoch 48/150
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0223 - val_loss: 0.0307
#
# Epoch 00048: val_loss improved from 0.03128 to 0.03074, saving model to weights.h5
# Epoch 49/150
# 3/3 [==============================] - 1s 243ms/step - loss: 0.0229 - val_loss: 0.0303
#
# Epoch 00049: val_loss improved from 0.03074 to 0.03034, saving model to weights.h5
# Epoch 50/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0250 - val_loss: 0.0301
#
# Epoch 00050: val_loss improved from 0.03034 to 0.03008, saving model to weights.h5
# Epoch 51/150
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0240 - val_loss: 0.0295
#
# Epoch 00051: val_loss improved from 0.03008 to 0.02948, saving model to weights.h5
# Epoch 52/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0233 - val_loss: 0.0289
#
# Epoch 00052: val_loss improved from 0.02948 to 0.02890, saving model to weights.h5
# Epoch 53/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0231 - val_loss: 0.0298
#
# Epoch 00053: val_loss did not improve from 0.02890
# Epoch 54/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0244 - val_loss: 0.0284
#
# Epoch 00054: val_loss improved from 0.02890 to 0.02836, saving model to weights.h5
# Epoch 55/150
# 3/3 [==============================] - 1s 237ms/step - loss: 0.0219 - val_loss: 0.0283
#
# Epoch 00055: val_loss improved from 0.02836 to 0.02825, saving model to weights.h5
# Epoch 56/150
# 3/3 [==============================] - 1s 237ms/step - loss: 0.0214 - val_loss: 0.0285
#
# Epoch 00056: val_loss did not improve from 0.02825
# Epoch 57/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0236 - val_loss: 0.0282
#
# Epoch 00057: val_loss improved from 0.02825 to 0.02825, saving model to weights.h5
# Epoch 58/150
# 3/3 [==============================] - 1s 235ms/step - loss: 0.0248 - val_loss: 0.0277
#
# Epoch 00058: val_loss improved from 0.02825 to 0.02772, saving model to weights.h5
# Epoch 59/150
# 3/3 [==============================] - 1s 229ms/step - loss: 0.0238 - val_loss: 0.0275
#
# Epoch 00059: val_loss improved from 0.02772 to 0.02750, saving model to weights.h5
# Epoch 60/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0215 - val_loss: 0.0276
#
# Epoch 00060: val_loss did not improve from 0.02750
# Epoch 61/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0229 - val_loss: 0.0268
#
# Epoch 00061: val_loss improved from 0.02750 to 0.02677, saving model to weights.h5
# Epoch 62/150
# 3/3 [==============================] - 1s 226ms/step - loss: 0.0218 - val_loss: 0.0270
#
# Epoch 00062: val_loss did not improve from 0.02677
# Epoch 63/150
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0256 - val_loss: 0.0265
#
# Epoch 00063: val_loss improved from 0.02677 to 0.02653, saving model to weights.h5
# Epoch 64/150
# 3/3 [==============================] - 1s 243ms/step - loss: 0.0225 - val_loss: 0.0270
#
# Epoch 00064: val_loss did not improve from 0.02653
# Epoch 65/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0236 - val_loss: 0.0275
#
# Epoch 00065: val_loss did not improve from 0.02653
# Epoch 66/150
# 3/3 [==============================] - 1s 235ms/step - loss: 0.0227 - val_loss: 0.0276
#
# Epoch 00066: val_loss did not improve from 0.02653
# Epoch 67/150
# 3/3 [==============================] - 1s 233ms/step - loss: 0.0235 - val_loss: 0.0267
#
# Epoch 00067: val_loss did not improve from 0.02653
# Epoch 68/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0207 - val_loss: 0.0257
#
# Epoch 00068: val_loss improved from 0.02653 to 0.02571, saving model to weights.h5
# Epoch 69/150
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0214 - val_loss: 0.0255
#
# Epoch 00069: val_loss improved from 0.02571 to 0.02553, saving model to weights.h5
# Epoch 70/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0220 - val_loss: 0.0252
#
# Epoch 00070: val_loss improved from 0.02553 to 0.02520, saving model to weights.h5
# Epoch 71/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0216 - val_loss: 0.0252
#
# Epoch 00071: val_loss did not improve from 0.02520
# Epoch 72/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0206 - val_loss: 0.0252
#
# Epoch 00072: val_loss did not improve from 0.02520
# Epoch 73/150
# 3/3 [==============================] - 1s 225ms/step - loss: 0.0218 - val_loss: 0.0254
#
# Epoch 00073: val_loss did not improve from 0.02520
# Epoch 74/150
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0233 - val_loss: 0.0247
#
# Epoch 00074: val_loss improved from 0.02520 to 0.02473, saving model to weights.h5
# Epoch 75/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0208 - val_loss: 0.0263
#
# Epoch 00075: val_loss did not improve from 0.02473
# Epoch 76/150
# 3/3 [==============================] - 1s 237ms/step - loss: 0.0224 - val_loss: 0.0252
#
# Epoch 00076: val_loss did not improve from 0.02473
# Epoch 77/150
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0230 - val_loss: 0.0245
#
# Epoch 00077: val_loss improved from 0.02473 to 0.02453, saving model to weights.h5
# Epoch 78/150
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0234 - val_loss: 0.0257
#
# Epoch 00078: val_loss did not improve from 0.02453
# Epoch 79/150
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0214 - val_loss: 0.0250
#
# Epoch 00079: val_loss did not improve from 0.02453
# Epoch 80/150
# 3/3 [==============================] - 1s 226ms/step - loss: 0.0207 - val_loss: 0.0253
#
# Epoch 00080: val_loss did not improve from 0.02453
# Epoch 81/150
# 3/3 [==============================] - 1s 233ms/step - loss: 0.0210 - val_loss: 0.0260
#
# Epoch 00081: val_loss did not improve from 0.02453
# Epoch 82/150
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0209 - val_loss: 0.0253
#
# Epoch 00082: val_loss did not improve from 0.02453
# Epoch 83/150
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0224 - val_loss: 0.0255
#
# Epoch 00083: val_loss did not improve from 0.02453
# Epoch 84/150
# 3/3 [==============================] - 1s 227ms/step - loss: 0.0186 - val_loss: 0.0241
#
# Epoch 00084: val_loss improved from 0.02453 to 0.02414, saving model to weights.h5
# Epoch 85/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0230 - val_loss: 0.0226
#
# Epoch 00085: val_loss improved from 0.02414 to 0.02262, saving model to weights.h5
# Epoch 86/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0214 - val_loss: 0.0250
#
# Epoch 00086: val_loss did not improve from 0.02262
# Epoch 87/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0229 - val_loss: 0.0232
#
# Epoch 00087: val_loss did not improve from 0.02262
# Epoch 88/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0187 - val_loss: 0.0233
#
# Epoch 00088: val_loss did not improve from 0.02262
# Epoch 89/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0214 - val_loss: 0.0234
#
# Epoch 00089: val_loss did not improve from 0.02262
# Epoch 90/150
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0191 - val_loss: 0.0235
#
# Epoch 00090: val_loss did not improve from 0.02262
# Epoch 91/150
# 3/3 [==============================] - 1s 233ms/step - loss: 0.0186 - val_loss: 0.0232
#
# Epoch 00091: val_loss did not improve from 0.02262
# Epoch 92/150
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0195 - val_loss: 0.0258
#
# Epoch 00092: val_loss did not improve from 0.02262
# Epoch 93/150
# 3/3 [==============================] - 1s 245ms/step - loss: 0.0200 - val_loss: 0.0230
#
# Epoch 00093: val_loss did not improve from 0.02262
# Epoch 94/150
# 3/3 [==============================] - 1s 241ms/step - loss: 0.0183 - val_loss: 0.0228
#
# Epoch 00094: val_loss did not improve from 0.02262
# Epoch 95/150
# 3/3 [==============================] - 1s 229ms/step - loss: 0.0225 - val_loss: 0.0228
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00095: val_loss did not improve from 0.02262
# Epoch 96/150
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0172

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:2].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 762.3750794799813

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-37-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
