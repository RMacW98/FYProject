# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    900
# sma      900
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:2].values
valid_set = data2.iloc[650:, 1:2].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 10))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 200, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 256)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 20s 5s/step - loss: 0.2681 - val_loss: 0.2748
#
# Epoch 00001: val_loss improved from inf to 0.27479, saving model to weights.h5
# Epoch 2/200
# 3/3 [==============================] - 1s 351ms/step - loss: 0.2196 - val_loss: 0.2016
#
# Epoch 00002: val_loss improved from 0.27479 to 0.20157, saving model to weights.h5
# Epoch 3/200
# 3/3 [==============================] - 1s 319ms/step - loss: 0.1500 - val_loss: 0.1168
#
# Epoch 00003: val_loss improved from 0.20157 to 0.11681, saving model to weights.h5
# Epoch 4/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.0902 - val_loss: 0.0682
#
# Epoch 00004: val_loss improved from 0.11681 to 0.06819, saving model to weights.h5
# Epoch 5/200
# 3/3 [==============================] - 1s 332ms/step - loss: 0.0594 - val_loss: 0.0611
#
# Epoch 00005: val_loss improved from 0.06819 to 0.06109, saving model to weights.h5
# Epoch 6/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.0503 - val_loss: 0.0516
#
# Epoch 00006: val_loss improved from 0.06109 to 0.05160, saving model to weights.h5
# Epoch 7/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0428 - val_loss: 0.0496
#
# Epoch 00007: val_loss improved from 0.05160 to 0.04960, saving model to weights.h5
# Epoch 8/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.0376 - val_loss: 0.0481
#
# Epoch 00008: val_loss improved from 0.04960 to 0.04810, saving model to weights.h5
# Epoch 9/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.0350 - val_loss: 0.0460
#
# Epoch 00009: val_loss improved from 0.04810 to 0.04599, saving model to weights.h5
# Epoch 10/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0289 - val_loss: 0.0470
#
# Epoch 00010: val_loss did not improve from 0.04599
# Epoch 11/200
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0284 - val_loss: 0.0464
#
# Epoch 00011: val_loss did not improve from 0.04599
# Epoch 12/200
# 3/3 [==============================] - 1s 315ms/step - loss: 0.0264 - val_loss: 0.0469
#
# Epoch 00012: val_loss did not improve from 0.04599
# Epoch 13/200
# 3/3 [==============================] - 1s 330ms/step - loss: 0.0264 - val_loss: 0.0444
#
# Epoch 00013: val_loss improved from 0.04599 to 0.04441, saving model to weights.h5
# Epoch 14/200
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0245 - val_loss: 0.0419
#
# Epoch 00014: val_loss improved from 0.04441 to 0.04187, saving model to weights.h5
# Epoch 15/200
# 3/3 [==============================] - 1s 330ms/step - loss: 0.0241 - val_loss: 0.0403
#
# Epoch 00015: val_loss improved from 0.04187 to 0.04033, saving model to weights.h5
# Epoch 16/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.0234 - val_loss: 0.0370
#
# Epoch 00016: val_loss improved from 0.04033 to 0.03700, saving model to weights.h5
# Epoch 17/200
# 3/3 [==============================] - 1s 332ms/step - loss: 0.0237 - val_loss: 0.0353
#
# Epoch 00017: val_loss improved from 0.03700 to 0.03530, saving model to weights.h5
# Epoch 18/200
# 3/3 [==============================] - 1s 341ms/step - loss: 0.0221 - val_loss: 0.0357
#
# Epoch 00018: val_loss did not improve from 0.03530
# Epoch 19/200
# 3/3 [==============================] - 1s 342ms/step - loss: 0.0223 - val_loss: 0.0329
#
# Epoch 00019: val_loss improved from 0.03530 to 0.03289, saving model to weights.h5
# Epoch 20/200
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0217 - val_loss: 0.0335
#
# Epoch 00020: val_loss did not improve from 0.03289
# Epoch 21/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0200 - val_loss: 0.0327
#
# Epoch 00021: val_loss improved from 0.03289 to 0.03273, saving model to weights.h5
# Epoch 22/200
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0198 - val_loss: 0.0326
#
# Epoch 00022: val_loss improved from 0.03273 to 0.03259, saving model to weights.h5
# Epoch 23/200
# 3/3 [==============================] - 1s 319ms/step - loss: 0.0208 - val_loss: 0.0317
#
# Epoch 00023: val_loss improved from 0.03259 to 0.03174, saving model to weights.h5
# Epoch 24/200
# 3/3 [==============================] - 1s 347ms/step - loss: 0.0196 - val_loss: 0.0309
#
# Epoch 00024: val_loss improved from 0.03174 to 0.03093, saving model to weights.h5
# Epoch 25/200
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0198 - val_loss: 0.0308
#
# Epoch 00025: val_loss improved from 0.03093 to 0.03078, saving model to weights.h5
# Epoch 26/200
# 3/3 [==============================] - 1s 326ms/step - loss: 0.0191 - val_loss: 0.0298
#
# Epoch 00026: val_loss improved from 0.03078 to 0.02982, saving model to weights.h5
# Epoch 27/200
# 3/3 [==============================] - 1s 344ms/step - loss: 0.0191 - val_loss: 0.0313
#
# Epoch 00027: val_loss did not improve from 0.02982
# Epoch 28/200
# 3/3 [==============================] - 1s 323ms/step - loss: 0.0184 - val_loss: 0.0296
#
# Epoch 00028: val_loss improved from 0.02982 to 0.02963, saving model to weights.h5
# Epoch 29/200
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0175 - val_loss: 0.0306
#
# Epoch 00029: val_loss did not improve from 0.02963
# Epoch 30/200
# 3/3 [==============================] - 1s 347ms/step - loss: 0.0165 - val_loss: 0.0302
#
# Epoch 00030: val_loss did not improve from 0.02963
# Epoch 31/200
# 3/3 [==============================] - 1s 351ms/step - loss: 0.0177 - val_loss: 0.0292
#
# Epoch 00031: val_loss improved from 0.02963 to 0.02922, saving model to weights.h5
# Epoch 32/200
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0184 - val_loss: 0.0283
#
# Epoch 00032: val_loss improved from 0.02922 to 0.02827, saving model to weights.h5
# Epoch 33/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0181 - val_loss: 0.0301
#
# Epoch 00033: val_loss did not improve from 0.02827
# Epoch 34/200
# 3/3 [==============================] - 1s 318ms/step - loss: 0.0176 - val_loss: 0.0274
#
# Epoch 00034: val_loss improved from 0.02827 to 0.02742, saving model to weights.h5
# Epoch 35/200
# 3/3 [==============================] - 1s 318ms/step - loss: 0.0167 - val_loss: 0.0276
#
# Epoch 00035: val_loss did not improve from 0.02742
# Epoch 36/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0170 - val_loss: 0.0271
#
# Epoch 00036: val_loss improved from 0.02742 to 0.02709, saving model to weights.h5
# Epoch 37/200
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0166 - val_loss: 0.0275
#
# Epoch 00037: val_loss did not improve from 0.02709
# Epoch 38/200
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0168 - val_loss: 0.0273
#
# Epoch 00038: val_loss did not improve from 0.02709
# Epoch 39/200
# 3/3 [==============================] - 1s 317ms/step - loss: 0.0158 - val_loss: 0.0265
#
# Epoch 00039: val_loss improved from 0.02709 to 0.02646, saving model to weights.h5
# Epoch 40/200
# 3/3 [==============================] - 1s 358ms/step - loss: 0.0169 - val_loss: 0.0283
#
# Epoch 00040: val_loss did not improve from 0.02646
# Epoch 41/200
# 3/3 [==============================] - 1s 352ms/step - loss: 0.0168 - val_loss: 0.0263
#
# Epoch 00041: val_loss improved from 0.02646 to 0.02631, saving model to weights.h5
# Epoch 42/200
# 3/3 [==============================] - 1s 355ms/step - loss: 0.0154 - val_loss: 0.0285
#
# Epoch 00042: val_loss did not improve from 0.02631
# Epoch 43/200
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0152 - val_loss: 0.0256
#
# Epoch 00043: val_loss improved from 0.02631 to 0.02557, saving model to weights.h5
# Epoch 44/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0164 - val_loss: 0.0300
#
# Epoch 00044: val_loss did not improve from 0.02557
# Epoch 45/200
# 3/3 [==============================] - 1s 318ms/step - loss: 0.0165 - val_loss: 0.0261
#
# Epoch 00045: val_loss did not improve from 0.02557
# Epoch 46/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0159 - val_loss: 0.0272
#
# Epoch 00046: val_loss did not improve from 0.02557
# Epoch 47/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0149 - val_loss: 0.0249
#
# Epoch 00047: val_loss improved from 0.02557 to 0.02488, saving model to weights.h5
# Epoch 48/200
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0153 - val_loss: 0.0259
#
# Epoch 00048: val_loss did not improve from 0.02488
# Epoch 49/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0146 - val_loss: 0.0253
#
# Epoch 00049: val_loss did not improve from 0.02488
# Epoch 50/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0135 - val_loss: 0.0250
#
# Epoch 00050: val_loss did not improve from 0.02488
# Epoch 51/200
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0146 - val_loss: 0.0286
#
# Epoch 00051: val_loss did not improve from 0.02488
# Epoch 52/200
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0154 - val_loss: 0.0246
#
# Epoch 00052: val_loss improved from 0.02488 to 0.02465, saving model to weights.h5
# Epoch 53/200
# 3/3 [==============================] - 1s 344ms/step - loss: 0.0165 - val_loss: 0.0296
#
# Epoch 00053: val_loss did not improve from 0.02465
# Epoch 54/200
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0142 - val_loss: 0.0223
#
# Epoch 00054: val_loss improved from 0.02465 to 0.02228, saving model to weights.h5
# Epoch 55/200
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0140 - val_loss: 0.0276
#
# Epoch 00055: val_loss did not improve from 0.02228
# Epoch 56/200
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0141 - val_loss: 0.0229
#
# Epoch 00056: val_loss did not improve from 0.02228
# Epoch 57/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0145 - val_loss: 0.0277
#
# Epoch 00057: val_loss did not improve from 0.02228
# Epoch 58/200
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0153 - val_loss: 0.0224
#
# Epoch 00058: val_loss did not improve from 0.02228
# Epoch 59/200
# 3/3 [==============================] - 1s 348ms/step - loss: 0.0156 - val_loss: 0.0237
#
# Epoch 00059: val_loss did not improve from 0.02228
# Epoch 60/200
# 3/3 [==============================] - 1s 356ms/step - loss: 0.0134 - val_loss: 0.0243
#
# Epoch 00060: val_loss did not improve from 0.02228
# Epoch 61/200
# 3/3 [==============================] - 1s 360ms/step - loss: 0.0134 - val_loss: 0.0214
#
# Epoch 00061: val_loss improved from 0.02228 to 0.02135, saving model to weights.h5
# Epoch 62/200
# 3/3 [==============================] - 1s 355ms/step - loss: 0.0145 - val_loss: 0.0262
#
# Epoch 00062: val_loss did not improve from 0.02135
# Epoch 63/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0132 - val_loss: 0.0229
#
# Epoch 00063: val_loss did not improve from 0.02135
# Epoch 64/200
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0123 - val_loss: 0.0259
#
# Epoch 00064: val_loss did not improve from 0.02135
# Epoch 65/200
# 3/3 [==============================] - 1s 330ms/step - loss: 0.0125 - val_loss: 0.0211
#
# Epoch 00065: val_loss improved from 0.02135 to 0.02113, saving model to weights.h5
# Epoch 66/200
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0130 - val_loss: 0.0235
#
# Epoch 00066: val_loss did not improve from 0.02113
# Epoch 67/200
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0125 - val_loss: 0.0213
#
# Epoch 00067: val_loss did not improve from 0.02113
# Epoch 68/200
# 3/3 [==============================] - 1s 335ms/step - loss: 0.0116 - val_loss: 0.0218
#
# Epoch 00068: val_loss did not improve from 0.02113
# Epoch 69/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0120 - val_loss: 0.0217
#
# Epoch 00069: val_loss did not improve from 0.02113
# Epoch 70/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0114

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:2].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
