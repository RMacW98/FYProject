# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    878
# sma      878
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:3].values
valid_set = data2.iloc[650:, 1:3].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 5, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 5, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 5, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 5))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 100, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 1)
# Out:
# Epoch 1/100
# 590/590 [==============================] - 22s 30ms/step - loss: 0.0762 - val_loss: 0.0359
#
# Epoch 00001: val_loss improved from inf to 0.03587, saving model to weights.h5
# Epoch 2/100
# 590/590 [==============================] - 16s 28ms/step - loss: 0.0293 - val_loss: 0.0333
#
# Epoch 00002: val_loss improved from 0.03587 to 0.03330, saving model to weights.h5
# Epoch 3/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0223 - val_loss: 0.0406
#
# Epoch 00003: val_loss did not improve from 0.03330
# Epoch 4/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0212 - val_loss: 0.0326
#
# Epoch 00004: val_loss improved from 0.03330 to 0.03261, saving model to weights.h5
# Epoch 5/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0184 - val_loss: 0.0267
#
# Epoch 00005: val_loss improved from 0.03261 to 0.02669, saving model to weights.h5
# Epoch 6/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0169 - val_loss: 0.0245
#
# Epoch 00006: val_loss improved from 0.02669 to 0.02454, saving model to weights.h5
# Epoch 7/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0139 - val_loss: 0.0289
#
# Epoch 00007: val_loss did not improve from 0.02454
# Epoch 8/100
# 590/590 [==============================] - 13s 22ms/step - loss: 0.0125 - val_loss: 0.0251
#
# Epoch 00008: val_loss did not improve from 0.02454
# Epoch 9/100
# 590/590 [==============================] - 13s 22ms/step - loss: 0.0103 - val_loss: 0.0236
#
# Epoch 00009: val_loss improved from 0.02454 to 0.02359, saving model to weights.h5
# Epoch 10/100
# 590/590 [==============================] - 13s 22ms/step - loss: 0.0122 - val_loss: 0.0200
#
# Epoch 00010: val_loss improved from 0.02359 to 0.01996, saving model to weights.h5
# Epoch 11/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0107 - val_loss: 0.0245
#
# Epoch 00011: val_loss did not improve from 0.01996
# Epoch 12/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0115 - val_loss: 0.0191
#
# Epoch 00012: val_loss improved from 0.01996 to 0.01908, saving model to weights.h5
# Epoch 13/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0108 - val_loss: 0.0154
#
# Epoch 00013: val_loss improved from 0.01908 to 0.01535, saving model to weights.h5
# Epoch 14/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0124 - val_loss: 0.0204
#
# Epoch 00014: val_loss did not improve from 0.01535
# Epoch 15/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0099 - val_loss: 0.0151
#
# Epoch 00015: val_loss improved from 0.01535 to 0.01514, saving model to weights.h5
# Epoch 16/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0111 - val_loss: 0.0158
#
# Epoch 00016: val_loss did not improve from 0.01514
# Epoch 17/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0103 - val_loss: 0.0147
#
# Epoch 00017: val_loss improved from 0.01514 to 0.01469, saving model to weights.h5
# Epoch 18/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0084 - val_loss: 0.0173
#
# Epoch 00018: val_loss did not improve from 0.01469
# Epoch 19/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0078 - val_loss: 0.0151
#
# Epoch 00019: val_loss did not improve from 0.01469
# Epoch 20/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0081 - val_loss: 0.0186
#
# Epoch 00020: val_loss did not improve from 0.01469
# Epoch 21/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0081 - val_loss: 0.0149
#
# Epoch 00021: val_loss did not improve from 0.01469
# Epoch 22/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0083 - val_loss: 0.0172
#
# Epoch 00022: val_loss did not improve from 0.01469
# Epoch 23/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0088 - val_loss: 0.0127
#
# Epoch 00023: val_loss improved from 0.01469 to 0.01272, saving model to weights.h5
# Epoch 24/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0072 - val_loss: 0.0146
#
# Epoch 00024: val_loss did not improve from 0.01272
# Epoch 25/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0083 - val_loss: 0.0141
#
# Epoch 00025: val_loss did not improve from 0.01272
# Epoch 26/100
# 590/590 [==============================] - 15s 26ms/step - loss: 0.0079 - val_loss: 0.0112
#
# Epoch 00026: val_loss improved from 0.01272 to 0.01116, saving model to weights.h5
# Epoch 27/100
# 590/590 [==============================] - 15s 26ms/step - loss: 0.0069 - val_loss: 0.0117
#
# Epoch 00027: val_loss did not improve from 0.01116
# Epoch 28/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0065 - val_loss: 0.0101
#
# Epoch 00028: val_loss improved from 0.01116 to 0.01014, saving model to weights.h5
# Epoch 29/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0072 - val_loss: 0.0106
#
# Epoch 00029: val_loss did not improve from 0.01014
# Epoch 30/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0063 - val_loss: 0.0094
#
# Epoch 00030: val_loss improved from 0.01014 to 0.00944, saving model to weights.h5
# Epoch 31/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00031: val_loss improved from 0.00944 to 0.00890, saving model to weights.h5
# Epoch 32/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0062 - val_loss: 0.0088
#
# Epoch 00032: val_loss improved from 0.00890 to 0.00883, saving model to weights.h5
# Epoch 33/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0068 - val_loss: 0.0133
#
# Epoch 00033: val_loss did not improve from 0.00883
# Epoch 34/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0067 - val_loss: 0.0090
#
# Epoch 00034: val_loss did not improve from 0.00883
# Epoch 35/100
# 590/590 [==============================] - 16s 27ms/step - loss: 0.0072 - val_loss: 0.0106
#
# Epoch 00035: val_loss did not improve from 0.00883
# Epoch 36/100
# 590/590 [==============================] - 16s 27ms/step - loss: 0.0068 - val_loss: 0.0087
#
# Epoch 00036: val_loss improved from 0.00883 to 0.00866, saving model to weights.h5
# Epoch 37/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0066 - val_loss: 0.0094
#
# Epoch 00037: val_loss did not improve from 0.00866
# Epoch 38/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0070 - val_loss: 0.0085
#
# Epoch 00038: val_loss improved from 0.00866 to 0.00853, saving model to weights.h5
# Epoch 39/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0064 - val_loss: 0.0103
#
# Epoch 00039: val_loss did not improve from 0.00853
# Epoch 40/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0059 - val_loss: 0.0097
#
# Epoch 00040: val_loss did not improve from 0.00853
# Epoch 41/100
# 590/590 [==============================] - 16s 26ms/step - loss: 0.0063 - val_loss: 0.0108
#
# Epoch 00041: val_loss did not improve from 0.00853
# Epoch 42/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0058 - val_loss: 0.0081
#
# Epoch 00042: val_loss improved from 0.00853 to 0.00813, saving model to weights.h5
# Epoch 43/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0077 - val_loss: 0.0094
#
# Epoch 00043: val_loss did not improve from 0.00813
# Epoch 44/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0057 - val_loss: 0.0084
#
# Epoch 00044: val_loss did not improve from 0.00813
# Epoch 45/100
# 590/590 [==============================] - 15s 26ms/step - loss: 0.0062 - val_loss: 0.0092
#
# Epoch 00045: val_loss did not improve from 0.00813
# Epoch 46/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0062 - val_loss: 0.0080
#
# Epoch 00046: val_loss improved from 0.00813 to 0.00797, saving model to weights.h5
# Epoch 47/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0065 - val_loss: 0.0076
#
# Epoch 00047: val_loss improved from 0.00797 to 0.00763, saving model to weights.h5
# Epoch 48/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0057 - val_loss: 0.0083
#
# Epoch 00048: val_loss did not improve from 0.00763
# Epoch 49/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0062 - val_loss: 0.0084
#
# Epoch 00049: val_loss did not improve from 0.00763
# Epoch 50/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0059 - val_loss: 0.0071
#
# Epoch 00050: val_loss improved from 0.00763 to 0.00714, saving model to weights.h5
# Epoch 51/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0065 - val_loss: 0.0068
#
# Epoch 00051: val_loss improved from 0.00714 to 0.00679, saving model to weights.h5
# Epoch 52/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0056 - val_loss: 0.0065
#
# Epoch 00052: val_loss improved from 0.00679 to 0.00650, saving model to weights.h5
# Epoch 53/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0059 - val_loss: 0.0083
#
# Epoch 00053: val_loss did not improve from 0.00650
# Epoch 54/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0058 - val_loss: 0.0066
#
# Epoch 00054: val_loss did not improve from 0.00650
# Epoch 55/100
# 590/590 [==============================] - 17s 28ms/step - loss: 0.0069 - val_loss: 0.0061
#
# Epoch 00055: val_loss improved from 0.00650 to 0.00608, saving model to weights.h5
# Epoch 56/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0064 - val_loss: 0.0067
#
# Epoch 00056: val_loss did not improve from 0.00608
# Epoch 57/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0075 - val_loss: 0.0062
#
# Epoch 00057: val_loss did not improve from 0.00608
# Epoch 58/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0060 - val_loss: 0.0060
#
# Epoch 00058: val_loss improved from 0.00608 to 0.00599, saving model to weights.h5
# Epoch 59/100
# 590/590 [==============================] - 17s 28ms/step - loss: 0.0062 - val_loss: 0.0074
#
# Epoch 00059: val_loss did not improve from 0.00599
# Epoch 60/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0056 - val_loss: 0.0084
#
# Epoch 00060: val_loss did not improve from 0.00599
# Epoch 61/100
# 590/590 [==============================] - 18s 31ms/step - loss: 0.0054 - val_loss: 0.0086
#
# Epoch 00061: val_loss did not improve from 0.00599
# Epoch 62/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0053 - val_loss: 0.0074
#
# Epoch 00062: val_loss did not improve from 0.00599
# Epoch 63/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0060 - val_loss: 0.0080
#
# Epoch 00063: val_loss did not improve from 0.00599
# Epoch 64/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0055 - val_loss: 0.0066
#
# Epoch 00064: val_loss did not improve from 0.00599
# Epoch 65/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0048 - val_loss: 0.0064
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00065: val_loss did not improve from 0.00599
# Epoch 66/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0058 - val_loss: 0.0074
#
# Epoch 00066: val_loss did not improve from 0.00599
# Epoch 67/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0060 - val_loss: 0.0067
#
# Epoch 00067: val_loss did not improve from 0.00599
# Epoch 68/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0059 - val_loss: 0.0053
#
# Epoch 00068: val_loss improved from 0.00599 to 0.00533, saving model to weights.h5
# Epoch 69/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0050 - val_loss: 0.0057
#
# Epoch 00069: val_loss did not improve from 0.00533
# Epoch 70/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0057 - val_loss: 0.0058
#
# Epoch 00070: val_loss did not improve from 0.00533
# Epoch 71/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0055 - val_loss: 0.0069
#
# Epoch 00071: val_loss did not improve from 0.00533
# Epoch 72/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0059 - val_loss: 0.0073
#
# Epoch 00072: val_loss did not improve from 0.00533
# Epoch 73/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0053 - val_loss: 0.0058
#
# Epoch 00073: val_loss did not improve from 0.00533
# Epoch 74/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0055 - val_loss: 0.0066
#
# Epoch 00074: val_loss did not improve from 0.00533
# Epoch 75/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0057 - val_loss: 0.0054
#
# Epoch 00075: val_loss did not improve from 0.00533
# Epoch 76/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0057 - val_loss: 0.0062
#
# Epoch 00076: val_loss did not improve from 0.00533
# Epoch 77/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0048 - val_loss: 0.0057
#
# Epoch 00077: val_loss did not improve from 0.00533
# Epoch 78/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0055 - val_loss: 0.0059
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00078: val_loss did not improve from 0.00533
# Epoch 79/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0044 - val_loss: 0.0053
#
# Epoch 00079: val_loss improved from 0.00533 to 0.00526, saving model to weights.h5
# Epoch 80/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0054 - val_loss: 0.0055
#
# Epoch 00080: val_loss did not improve from 0.00526
# Epoch 81/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0044 - val_loss: 0.0049
#
# Epoch 00081: val_loss improved from 0.00526 to 0.00493, saving model to weights.h5
# Epoch 82/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0054 - val_loss: 0.0052
#
# Epoch 00082: val_loss did not improve from 0.00493
# Epoch 83/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0052 - val_loss: 0.0052
#
# Epoch 00083: val_loss did not improve from 0.00493
# Epoch 84/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0054 - val_loss: 0.0060
#
# Epoch 00084: val_loss did not improve from 0.00493
# Epoch 85/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0044 - val_loss: 0.0050
#
# Epoch 00085: val_loss did not improve from 0.00493
# Epoch 86/100
# 590/590 [==============================] - 15s 26ms/step - loss: 0.0050 - val_loss: 0.0052
#
# Epoch 00086: val_loss did not improve from 0.00493
# Epoch 87/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0042 - val_loss: 0.0057
#
# Epoch 00087: val_loss did not improve from 0.00493
# Epoch 88/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0052 - val_loss: 0.0048
#
# Epoch 00088: val_loss improved from 0.00493 to 0.00481, saving model to weights.h5
# Epoch 89/100
# 590/590 [==============================] - 14s 23ms/step - loss: 0.0052 - val_loss: 0.0049
#
# Epoch 00089: val_loss did not improve from 0.00481
# Epoch 90/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0053 - val_loss: 0.0055
#
# Epoch 00090: val_loss did not improve from 0.00481
# Epoch 91/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0054 - val_loss: 0.0060
#
# Epoch 00091: val_loss did not improve from 0.00481
# Epoch 92/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0046 - val_loss: 0.0052
#
# Epoch 00092: val_loss did not improve from 0.00481
# Epoch 93/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0045 - val_loss: 0.0049
#
# Epoch 00093: val_loss did not improve from 0.00481
# Epoch 94/100
# 590/590 [==============================] - 13s 23ms/step - loss: 0.0044 - val_loss: 0.0048
#
# Epoch 00094: val_loss did not improve from 0.00481
# Epoch 95/100
# 590/590 [==============================] - 14s 25ms/step - loss: 0.0052 - val_loss: 0.0051
#
# Epoch 00095: val_loss did not improve from 0.00481
# Epoch 96/100
# 590/590 [==============================] - 16s 28ms/step - loss: 0.0054 - val_loss: 0.0050
#
# Epoch 00096: val_loss did not improve from 0.00481
# Epoch 97/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0052 - val_loss: 0.0050
#
# Epoch 00097: val_loss did not improve from 0.00481
# Epoch 98/100
# 590/590 [==============================] - 14s 24ms/step - loss: 0.0048 - val_loss: 0.0057
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00098: val_loss did not improve from 0.00481
# Epoch 99/100
# 590/590 [==============================] - 15s 26ms/step - loss: 0.0052 - val_loss: 0.0054
#
# Epoch 00099: val_loss did not improve from 0.00481
# Epoch 100/100
# 590/590 [==============================] - 15s 25ms/step - loss: 0.0045 - val_loss: 0.0050
#
# Epoch 00100: val_loss did not improve from 0.00481

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:3].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 371.730288180052

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-14-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
