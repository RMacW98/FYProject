# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    895
# sma      895
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:3].values
valid_set = data2.iloc[650:, 1:3].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 200, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 32)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 15s 417ms/step - loss: 0.1027 - val_loss: 0.0519
#
# Epoch 00001: val_loss improved from inf to 0.05193, saving model to weights.h5
# Epoch 2/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0264 - val_loss: 0.0408
#
# Epoch 00002: val_loss improved from 0.05193 to 0.04080, saving model to weights.h5
# Epoch 3/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0174 - val_loss: 0.0384
#
# Epoch 00003: val_loss improved from 0.04080 to 0.03839, saving model to weights.h5
# Epoch 4/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0145 - val_loss: 0.0376
#
# Epoch 00004: val_loss improved from 0.03839 to 0.03761, saving model to weights.h5
# Epoch 5/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0148 - val_loss: 0.0356
#
# Epoch 00005: val_loss improved from 0.03761 to 0.03561, saving model to weights.h5
# Epoch 6/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0129 - val_loss: 0.0271
#
# Epoch 00006: val_loss improved from 0.03561 to 0.02707, saving model to weights.h5
# Epoch 7/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0139 - val_loss: 0.0247
#
# Epoch 00007: val_loss improved from 0.02707 to 0.02474, saving model to weights.h5
# Epoch 8/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0121 - val_loss: 0.0261
#
# Epoch 00008: val_loss did not improve from 0.02474
# Epoch 9/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0106 - val_loss: 0.0215
#
# Epoch 00009: val_loss improved from 0.02474 to 0.02154, saving model to weights.h5
# Epoch 10/200
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0105 - val_loss: 0.0218
#
# Epoch 00010: val_loss did not improve from 0.02154
# Epoch 11/200
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0103 - val_loss: 0.0208
#
# Epoch 00011: val_loss improved from 0.02154 to 0.02079, saving model to weights.h5
# Epoch 12/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0096 - val_loss: 0.0190
#
# Epoch 00012: val_loss improved from 0.02079 to 0.01896, saving model to weights.h5
# Epoch 13/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0092 - val_loss: 0.0223
#
# Epoch 00013: val_loss did not improve from 0.01896
# Epoch 14/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0097 - val_loss: 0.0190
#
# Epoch 00014: val_loss did not improve from 0.01896
# Epoch 15/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0099 - val_loss: 0.0182
#
# Epoch 00015: val_loss improved from 0.01896 to 0.01824, saving model to weights.h5
# Epoch 16/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0096 - val_loss: 0.0207
#
# Epoch 00016: val_loss did not improve from 0.01824
# Epoch 17/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0073 - val_loss: 0.0170
#
# Epoch 00017: val_loss improved from 0.01824 to 0.01696, saving model to weights.h5
# Epoch 18/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0095 - val_loss: 0.0162
#
# Epoch 00018: val_loss improved from 0.01696 to 0.01617, saving model to weights.h5
# Epoch 19/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0091 - val_loss: 0.0160
#
# Epoch 00019: val_loss improved from 0.01617 to 0.01604, saving model to weights.h5
# Epoch 20/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0088 - val_loss: 0.0150
#
# Epoch 00020: val_loss improved from 0.01604 to 0.01496, saving model to weights.h5
# Epoch 21/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0070 - val_loss: 0.0148
#
# Epoch 00021: val_loss improved from 0.01496 to 0.01476, saving model to weights.h5
# Epoch 22/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0068 - val_loss: 0.0154
#
# Epoch 00022: val_loss did not improve from 0.01476
# Epoch 23/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0066 - val_loss: 0.0142
#
# Epoch 00023: val_loss improved from 0.01476 to 0.01421, saving model to weights.h5
# Epoch 24/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0075 - val_loss: 0.0140
#
# Epoch 00024: val_loss improved from 0.01421 to 0.01399, saving model to weights.h5
# Epoch 25/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0070 - val_loss: 0.0137
#
# Epoch 00025: val_loss improved from 0.01399 to 0.01370, saving model to weights.h5
# Epoch 26/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0062 - val_loss: 0.0134
#
# Epoch 00026: val_loss improved from 0.01370 to 0.01344, saving model to weights.h5
# Epoch 27/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0063 - val_loss: 0.0147
#
# Epoch 00027: val_loss did not improve from 0.01344
# Epoch 28/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0075 - val_loss: 0.0131
#
# Epoch 00028: val_loss improved from 0.01344 to 0.01314, saving model to weights.h5
# Epoch 29/200
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0064 - val_loss: 0.0129
#
# Epoch 00029: val_loss improved from 0.01314 to 0.01292, saving model to weights.h5
# Epoch 30/200
# 19/19 [==============================] - 1s 70ms/step - loss: 0.0058 - val_loss: 0.0130
#
# Epoch 00030: val_loss did not improve from 0.01292
# Epoch 31/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0063 - val_loss: 0.0127
#
# Epoch 00031: val_loss improved from 0.01292 to 0.01266, saving model to weights.h5
# Epoch 32/200
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0058 - val_loss: 0.0138
#
# Epoch 00032: val_loss did not improve from 0.01266
# Epoch 33/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0067 - val_loss: 0.0164
#
# Epoch 00033: val_loss did not improve from 0.01266
# Epoch 34/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0066 - val_loss: 0.0140
#
# Epoch 00034: val_loss did not improve from 0.01266
# Epoch 35/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0063 - val_loss: 0.0118
#
# Epoch 00035: val_loss improved from 0.01266 to 0.01182, saving model to weights.h5
# Epoch 36/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0055 - val_loss: 0.0118
#
# Epoch 00036: val_loss improved from 0.01182 to 0.01177, saving model to weights.h5
# Epoch 37/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0049 - val_loss: 0.0116
#
# Epoch 00037: val_loss improved from 0.01177 to 0.01157, saving model to weights.h5
# Epoch 38/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0054 - val_loss: 0.0116
#
# Epoch 00038: val_loss did not improve from 0.01157
# Epoch 39/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0050 - val_loss: 0.0128
#
# Epoch 00039: val_loss did not improve from 0.01157
# Epoch 40/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0054 - val_loss: 0.0113
#
# Epoch 00040: val_loss improved from 0.01157 to 0.01126, saving model to weights.h5
# Epoch 41/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0063 - val_loss: 0.0113
#
# Epoch 00041: val_loss did not improve from 0.01126
# Epoch 42/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0049 - val_loss: 0.0113
#
# Epoch 00042: val_loss did not improve from 0.01126
# Epoch 43/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0057 - val_loss: 0.0107
#
# Epoch 00043: val_loss improved from 0.01126 to 0.01069, saving model to weights.h5
# Epoch 44/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0055 - val_loss: 0.0112
#
# Epoch 00044: val_loss did not improve from 0.01069
# Epoch 45/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0045 - val_loss: 0.0111
#
# Epoch 00045: val_loss did not improve from 0.01069
# Epoch 46/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0050 - val_loss: 0.0101
#
# Epoch 00046: val_loss improved from 0.01069 to 0.01012, saving model to weights.h5
# Epoch 47/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0055 - val_loss: 0.0131
#
# Epoch 00047: val_loss did not improve from 0.01012
# Epoch 48/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0059 - val_loss: 0.0110
# Epoch 00048: val_loss did not improve from 0.01012
# Epoch 49/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0048 - val_loss: 0.0124
#
# Epoch 00049: val_loss did not improve from 0.01012
# Epoch 50/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0053 - val_loss: 0.0112
#
# Epoch 00050: val_loss did not improve from 0.01012
# Epoch 51/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0047 - val_loss: 0.0102
#
# Epoch 00051: val_loss did not improve from 0.01012
# Epoch 52/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0044 - val_loss: 0.0098
#
# Epoch 00052: val_loss improved from 0.01012 to 0.00979, saving model to weights.h5
# Epoch 53/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0046 - val_loss: 0.0103
#
# Epoch 00053: val_loss did not improve from 0.00979
# Epoch 54/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0043 - val_loss: 0.0096
#
# Epoch 00054: val_loss improved from 0.00979 to 0.00957, saving model to weights.h5
# Epoch 55/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0044 - val_loss: 0.0096
#
# Epoch 00055: val_loss improved from 0.00957 to 0.00955, saving model to weights.h5
# Epoch 56/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0046 - val_loss: 0.0098
#
# Epoch 00056: val_loss did not improve from 0.00955
# Epoch 57/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0043 - val_loss: 0.0112
#
# Epoch 00057: val_loss did not improve from 0.00955
# Epoch 58/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0045 - val_loss: 0.0100
#
# Epoch 00058: val_loss did not improve from 0.00955
# Epoch 59/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0046 - val_loss: 0.0092
#
# Epoch 00059: val_loss improved from 0.00955 to 0.00921, saving model to weights.h5
# Epoch 60/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0044 - val_loss: 0.0100
#
# Epoch 00060: val_loss did not improve from 0.00921
# Epoch 61/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0044 - val_loss: 0.0092
#
# Epoch 00061: val_loss improved from 0.00921 to 0.00920, saving model to weights.h5
# Epoch 62/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0041 - val_loss: 0.0089
#
# Epoch 00062: val_loss improved from 0.00920 to 0.00891, saving model to weights.h5
# Epoch 63/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0042 - val_loss: 0.0090
#
# Epoch 00063: val_loss did not improve from 0.00891
# Epoch 64/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0041 - val_loss: 0.0089
#
# Epoch 00064: val_loss improved from 0.00891 to 0.00888, saving model to weights.h5
# Epoch 65/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0041 - val_loss: 0.0087
#
# Epoch 00065: val_loss improved from 0.00888 to 0.00868, saving model to weights.h5
# Epoch 66/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0037 - val_loss: 0.0092
#
# Epoch 00066: val_loss did not improve from 0.00868
# Epoch 67/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0041 - val_loss: 0.0083
#
# Epoch 00067: val_loss improved from 0.00868 to 0.00832, saving model to weights.h5
# Epoch 68/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0045 - val_loss: 0.0088
#
# Epoch 00068: val_loss did not improve from 0.00832
# Epoch 69/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0042 - val_loss: 0.0085
#
# Epoch 00069: val_loss did not improve from 0.00832
# Epoch 70/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0040 - val_loss: 0.0083
#
# Epoch 00070: val_loss improved from 0.00832 to 0.00832, saving model to weights.h5
# Epoch 71/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0040 - val_loss: 0.0084
#
# Epoch 00071: val_loss did not improve from 0.00832
# Epoch 72/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0038 - val_loss: 0.0085
#
# Epoch 00072: val_loss did not improve from 0.00832
# Epoch 73/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0048 - val_loss: 0.0083
#
# Epoch 00073: val_loss did not improve from 0.00832
# Epoch 74/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0040 - val_loss: 0.0082
#
# Epoch 00074: val_loss improved from 0.00832 to 0.00820, saving model to weights.h5
# Epoch 75/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0041 - val_loss: 0.0078
#
# Epoch 00075: val_loss improved from 0.00820 to 0.00783, saving model to weights.h5
# Epoch 76/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0043 - val_loss: 0.0079
#
# Epoch 00076: val_loss did not improve from 0.00783
# Epoch 77/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0040 - val_loss: 0.0077
#
# Epoch 00077: val_loss improved from 0.00783 to 0.00773, saving model to weights.h5
# Epoch 78/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0036 - val_loss: 0.0079
#
# Epoch 00078: val_loss did not improve from 0.00773
# Epoch 79/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0037 - val_loss: 0.0077
#
# Epoch 00079: val_loss improved from 0.00773 to 0.00768, saving model to weights.h5
# Epoch 80/200
# 19/19 [==============================] - 2s 98ms/step - loss: 0.0035 - val_loss: 0.0081
#
# Epoch 00080: val_loss did not improve from 0.00768
# Epoch 81/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0039 - val_loss: 0.0074
#
# Epoch 00081: val_loss improved from 0.00768 to 0.00745, saving model to weights.h5
# Epoch 82/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0044 - val_loss: 0.0078
#
# Epoch 00082: val_loss did not improve from 0.00745
# Epoch 83/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0040 - val_loss: 0.0072
#
# Epoch 00083: val_loss improved from 0.00745 to 0.00719, saving model to weights.h5
# Epoch 84/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0031 - val_loss: 0.0073
#
# Epoch 00084: val_loss did not improve from 0.00719
# Epoch 85/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0033 - val_loss: 0.0071
#
# Epoch 00085: val_loss improved from 0.00719 to 0.00711, saving model to weights.h5
# Epoch 86/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0031 - val_loss: 0.0072
#
# Epoch 00086: val_loss did not improve from 0.00711
# Epoch 87/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0034 - val_loss: 0.0070
#
# Epoch 00087: val_loss improved from 0.00711 to 0.00699, saving model to weights.h5
# Epoch 88/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0035 - val_loss: 0.0069
#
# Epoch 00088: val_loss improved from 0.00699 to 0.00689, saving model to weights.h5
# Epoch 89/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0031 - val_loss: 0.0075
#
# Epoch 00089: val_loss did not improve from 0.00689
# Epoch 90/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0038 - val_loss: 0.0071
#
# Epoch 00090: val_loss did not improve from 0.00689
# Epoch 91/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0028 - val_loss: 0.0069
#
# Epoch 00091: val_loss improved from 0.00689 to 0.00688, saving model to weights.h5
# Epoch 92/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0036 - val_loss: 0.0069
#
# Epoch 00092: val_loss improved from 0.00688 to 0.00687, saving model to weights.h5
# Epoch 93/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0033 - val_loss: 0.0077
#
# Epoch 00093: val_loss did not improve from 0.00687
# Epoch 94/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0042 - val_loss: 0.0084
#
# Epoch 00094: val_loss did not improve from 0.00687
# Epoch 95/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0046 - val_loss: 0.0065
#
# Epoch 00095: val_loss improved from 0.00687 to 0.00653, saving model to weights.h5
# Epoch 96/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0033 - val_loss: 0.0065
#
# Epoch 00096: val_loss did not improve from 0.00653
# Epoch 97/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0033 - val_loss: 0.0066
# Epoch 00097: val_loss did not improve from 0.00653
# Epoch 98/200
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0034 - val_loss: 0.0065
#
# Epoch 00098: val_loss improved from 0.00653 to 0.00649, saving model to weights.h5
# Epoch 99/200
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0039 - val_loss: 0.0067
#
# Epoch 00099: val_loss did not improve from 0.00649
# Epoch 100/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0035 - val_loss: 0.0063
#
# Epoch 00100: val_loss improved from 0.00649 to 0.00631, saving model to weights.h5
# Epoch 101/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00101: val_loss improved from 0.00631 to 0.00628, saving model to weights.h5
# Epoch 102/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0035 - val_loss: 0.0062
#
# Epoch 00102: val_loss improved from 0.00628 to 0.00624, saving model to weights.h5
# Epoch 103/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0038 - val_loss: 0.0083
#
# Epoch 00103: val_loss did not improve from 0.00624
# Epoch 104/200
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0039 - val_loss: 0.0062
#
# Epoch 00104: val_loss improved from 0.00624 to 0.00624, saving model to weights.h5
# Epoch 105/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0031 - val_loss: 0.0060
#
# Epoch 00105: val_loss improved from 0.00624 to 0.00599, saving model to weights.h5
# Epoch 106/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0031 - val_loss: 0.0058
#
# Epoch 00106: val_loss improved from 0.00599 to 0.00583, saving model to weights.h5
# Epoch 107/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0030 - val_loss: 0.0062
#
# Epoch 00107: val_loss did not improve from 0.00583
# Epoch 108/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0030 - val_loss: 0.0058
#
# Epoch 00108: val_loss improved from 0.00583 to 0.00575, saving model to weights.h5
# Epoch 109/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0028 - val_loss: 0.0059
#
# Epoch 00109: val_loss did not improve from 0.00575
# Epoch 110/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00110: val_loss did not improve from 0.00575
# Epoch 111/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0030 - val_loss: 0.0066
#
# Epoch 00111: val_loss did not improve from 0.00575
# Epoch 112/200
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0031 - val_loss: 0.0057
#
# Epoch 00112: val_loss improved from 0.00575 to 0.00568, saving model to weights.h5
# Epoch 113/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0033 - val_loss: 0.0056
#
# Epoch 00113: val_loss improved from 0.00568 to 0.00555, saving model to weights.h5
# Epoch 114/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0027 - val_loss: 0.0055
#
# Epoch 00114: val_loss improved from 0.00555 to 0.00549, saving model to weights.h5
# Epoch 115/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0031 - val_loss: 0.0058
#
# Epoch 00115: val_loss did not improve from 0.00549
# Epoch 116/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0031 - val_loss: 0.0057
#
# Epoch 00116: val_loss did not improve from 0.00549
# Epoch 117/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0034 - val_loss: 0.0055
#
# Epoch 00117: val_loss did not improve from 0.00549
# Epoch 118/200
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0027 - val_loss: 0.0054
#
# Epoch 00118: val_loss improved from 0.00549 to 0.00537, saving model to weights.h5
# Epoch 119/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0031 - val_loss: 0.0058
#
# Epoch 00119: val_loss did not improve from 0.00537
# Epoch 120/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0031 - val_loss: 0.0053
#
# Epoch 00120: val_loss improved from 0.00537 to 0.00528, saving model to weights.h5
# Epoch 121/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0033 - val_loss: 0.0052
#
# Epoch 00121: val_loss improved from 0.00528 to 0.00516, saving model to weights.h5
# Epoch 122/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0027 - val_loss: 0.0054
#
# Epoch 00122: val_loss did not improve from 0.00516
# Epoch 123/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0027 - val_loss: 0.0052
#
# Epoch 00123: val_loss improved from 0.00516 to 0.00516, saving model to weights.h5
# Epoch 124/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0032 - val_loss: 0.0052
#
# Epoch 00124: val_loss improved from 0.00516 to 0.00515, saving model to weights.h5
# Epoch 125/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0029 - val_loss: 0.0053
#
# Epoch 00125: val_loss did not improve from 0.00515
# Epoch 126/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0032 - val_loss: 0.0050
#
# Epoch 00126: val_loss improved from 0.00515 to 0.00496, saving model to weights.h5
# Epoch 127/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0027 - val_loss: 0.0051
#
# Epoch 00127: val_loss did not improve from 0.00496
# Epoch 128/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0030 - val_loss: 0.0049
#
# Epoch 00128: val_loss improved from 0.00496 to 0.00489, saving model to weights.h5
# Epoch 129/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0031 - val_loss: 0.0050
#
# Epoch 00129: val_loss did not improve from 0.00489
# Epoch 130/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0028 - val_loss: 0.0057
#
# Epoch 00130: val_loss did not improve from 0.00489
# Epoch 131/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0035 - val_loss: 0.0049
#
# Epoch 00131: val_loss did not improve from 0.00489
# Epoch 132/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0031 - val_loss: 0.0050
#
# Epoch 00132: val_loss did not improve from 0.00489
# Epoch 133/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0022 - val_loss: 0.0049
#
# Epoch 00133: val_loss did not improve from 0.00489
# Epoch 134/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0025 - val_loss: 0.0049
#
# Epoch 00134: val_loss did not improve from 0.00489
# Epoch 135/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0029 - val_loss: 0.0057
#
# Epoch 00135: val_loss did not improve from 0.00489
# Epoch 136/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0029 - val_loss: 0.0051
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00136: val_loss did not improve from 0.00489
# Epoch 137/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0024 - val_loss: 0.0049
#
# Epoch 00137: val_loss improved from 0.00489 to 0.00485, saving model to weights.h5
# Epoch 138/200
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00138: val_loss improved from 0.00485 to 0.00468, saving model to weights.h5
# Epoch 139/200
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00139: val_loss did not improve from 0.00468
# Epoch 140/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00140: val_loss did not improve from 0.00468
# Epoch 141/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0021 - val_loss: 0.0047
#
# Epoch 00141: val_loss did not improve from 0.00468
# Epoch 142/200
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00142: val_loss did not improve from 0.00468
# Epoch 143/200
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00143: val_loss improved from 0.00468 to 0.00458, saving model to weights.h5
# Epoch 144/200
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0021 - val_loss: 0.0049
#
# Epoch 00144: val_loss did not improve from 0.00458
# Epoch 145/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00145: val_loss did not improve from 0.00458
# Epoch 146/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0021 - val_loss: 0.0046
#
# Epoch 00146: val_loss improved from 0.00458 to 0.00455, saving model to weights.h5
# Epoch 147/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0023 - val_loss: 0.0045
#
# Epoch 00147: val_loss improved from 0.00455 to 0.00454, saving model to weights.h5
# Epoch 148/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0047
#
# Epoch 00148: val_loss did not improve from 0.00454
# Epoch 149/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0047
#
# Epoch 00149: val_loss did not improve from 0.00454
# Epoch 150/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0022 - val_loss: 0.0045
#
# Epoch 00150: val_loss improved from 0.00454 to 0.00447, saving model to weights.h5
# Epoch 151/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0024 - val_loss: 0.0049
#
# Epoch 00151: val_loss did not improve from 0.00447
# Epoch 152/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00152: val_loss did not improve from 0.00447
# Epoch 153/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0021 - val_loss: 0.0045
#
# Epoch 00153: val_loss did not improve from 0.00447
# Epoch 154/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0026 - val_loss: 0.0045
#
# Epoch 00154: val_loss did not improve from 0.00447
# Epoch 155/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0028 - val_loss: 0.0052
#
# Epoch 00155: val_loss did not improve from 0.00447
# Epoch 156/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0026 - val_loss: 0.0048
#
# Epoch 00156: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00156: val_loss did not improve from 0.00447
# Epoch 157/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0021 - val_loss: 0.0045
#
# Epoch 00157: val_loss improved from 0.00447 to 0.00446, saving model to weights.h5
# Epoch 158/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0020 - val_loss: 0.0045
#
# Epoch 00158: val_loss did not improve from 0.00446
# Epoch 159/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00159: val_loss improved from 0.00446 to 0.00440, saving model to weights.h5
# Epoch 160/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00160: val_loss did not improve from 0.00440
# Epoch 161/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0020 - val_loss: 0.0045
#
# Epoch 00161: val_loss did not improve from 0.00440
# Epoch 162/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00162: val_loss improved from 0.00440 to 0.00439, saving model to weights.h5
# Epoch 163/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0044
#
# Epoch 00163: val_loss did not improve from 0.00439
# Epoch 164/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0021 - val_loss: 0.0044
#
# Epoch 00164: val_loss did not improve from 0.00439
# Epoch 165/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0020 - val_loss: 0.0044
#
# Epoch 00165: val_loss did not improve from 0.00439
# Epoch 166/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00166: val_loss did not improve from 0.00439
# Epoch 167/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00167: val_loss did not improve from 0.00439
# Epoch 168/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0025 - val_loss: 0.0045
#
# Epoch 00168: val_loss did not improve from 0.00439
# Epoch 169/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0029 - val_loss: 0.0044
#
# Epoch 00169: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00169: val_loss improved from 0.00439 to 0.00435, saving model to weights.h5
# Epoch 170/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0020 - val_loss: 0.0044
#
# Epoch 00170: val_loss did not improve from 0.00435
# Epoch 171/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0020 - val_loss: 0.0045
#
# Epoch 00171: val_loss did not improve from 0.00435
# Epoch 172/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0043
#
# Epoch 00172: val_loss improved from 0.00435 to 0.00432, saving model to weights.h5
# Epoch 173/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0044
#
# Epoch 00173: val_loss did not improve from 0.00432
# Epoch 174/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00174: val_loss did not improve from 0.00432
# Epoch 175/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0045
#
# Epoch 00175: val_loss did not improve from 0.00432
# Epoch 176/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0021 - val_loss: 0.0044
#
# Epoch 00176: val_loss did not improve from 0.00432
# Epoch 177/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00177: val_loss did not improve from 0.00432
# Epoch 178/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00178: val_loss did not improve from 0.00432
# Epoch 179/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0019 - val_loss: 0.0044
#
# Epoch 00179: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00179: val_loss did not improve from 0.00432
# Epoch 180/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0020 - val_loss: 0.0044
#
# Epoch 00180: val_loss did not improve from 0.00432
# Epoch 181/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0026 - val_loss: 0.0043
#
# Epoch 00181: val_loss did not improve from 0.00432
# Epoch 182/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00182: val_loss improved from 0.00432 to 0.00432, saving model to weights.h5
# Epoch 183/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0043
#
# Epoch 00183: val_loss improved from 0.00432 to 0.00430, saving model to weights.h5
# Epoch 184/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00184: val_loss did not improve from 0.00430
# Epoch 185/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0021 - val_loss: 0.0044
#
# Epoch 00185: val_loss did not improve from 0.00430
# Epoch 186/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0023 - val_loss: 0.0043
#
# Epoch 00186: val_loss did not improve from 0.00430
# Epoch 187/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0020 - val_loss: 0.0043
#
# Epoch 00187: val_loss improved from 0.00430 to 0.00430, saving model to weights.h5
# Epoch 188/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00188: val_loss did not improve from 0.00430
# Epoch 189/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0020 - val_loss: 0.0043
#
# Epoch 00189: val_loss improved from 0.00430 to 0.00429, saving model to weights.h5
# Epoch 190/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00190: val_loss did not improve from 0.00429
# Epoch 191/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0021 - val_loss: 0.0043
#
# Epoch 00191: val_loss did not improve from 0.00429
# Epoch 192/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0021 - val_loss: 0.0043
#
# Epoch 00192: val_loss improved from 0.00429 to 0.00429, saving model to weights.h5
# Epoch 193/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0044
#
# Epoch 00193: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00193: val_loss did not improve from 0.00429
# Epoch 194/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0026 - val_loss: 0.0044
#
# Epoch 00194: val_loss did not improve from 0.00429
# Epoch 195/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0043
#
# Epoch 00195: val_loss did not improve from 0.00429
# Epoch 196/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0021 - val_loss: 0.0043
#
# Epoch 00196: val_loss did not improve from 0.00429
# Epoch 197/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0021 - val_loss: 0.0043
#
# Epoch 00197: val_loss did not improve from 0.00429
# Epoch 198/200
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0020 - val_loss: 0.0043
#
# Epoch 00198: val_loss improved from 0.00429 to 0.00428, saving model to weights.h5
# Epoch 199/200
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00199: val_loss did not improve from 0.00428
# Epoch 200/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00200: val_loss did not improve from 0.00428

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:3].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 352.6481354518187

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-17-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
