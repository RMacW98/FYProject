# %%
import psycopg2
import pandas as pd
from newsapi import NewsApiClient
# Create your views here.
top_headlines = pd.DataFrame(columns=['title', 'desc', 'outlet', 'img', 'url', 'publishedAt'])

def index():
    newsapi = NewsApiClient(api_key='cc3f4e3191f149658f3922e9c47ec1ad')
    headlines = newsapi.get_top_headlines(q='bitcoin',
                         category='business',
                         language='en')
    articles = headlines['articles']
    source = []
    desc = []
    news = []
    img = []
    url = []
    published = []

    for i in range(len(articles)):
        article = articles[i]
        source.append(article['source']['name'])
        desc.append(article['description'])
        news.append(article['title'])
        img.append(article['urlToImage'])
        url.append(article['url'])
        published.append(article['publishedAt'])
        
    top_headlines['title'] = news
    top_headlines['desc'] = desc
    top_headlines['outlet'] = source
    top_headlines['img'] = img
    top_headlines['url'] = url
    top_headlines['publishedAt'] = published
    
    top_headlines['title'] = top_headlines['title'].str.replace("'", "\''")
    top_headlines['desc'] = top_headlines['desc'].str.replace("'", "\''")
    
    top_headlines['publishedAt'] = pd.to_datetime(top_headlines['publishedAt']).dt.strftime('%Y-%m-%d %H:%M')
    
    
    return top_headlines

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()


    def insert_db(self, df):
        cur = self.con.cursor()
        

        for i in range(len(df)):
            cur.execute(
                'INSERT INTO "newsApp_article" (title, description, pic, url, date_posted, outlet)'
                f" VALUES ('{df['title'][i]}','{df['desc'][i]}','{df['img'][i]}','{df['url'][i]}','{df['publishedAt'][i]}'::timestamp,'{df['outlet'][i]}');")

        self.con.commit()

        self.con.close()

# %%
if __name__ == "__main__":
    database_client = DatabaseClient()

    top_stories = index()
    #database_client.insert_db(top_stories)

# %%
top_stories
# Out:
#                                                title  \
# 0  Meet the Millennial investor not giving in to ...
# 1  One in Three Investors Feel They’ve Missed the...
# 2  Price analysis 3/10: BTC, ETH, BNB, ADA, DOT, ...
# 3  3 key Bitcoin price metrics signal this ‘healt...
# 4  Bitcoin: It’s not all about the price! - AMBCr...
# 5  Bitcoin a ''threat to international safety'', ...
# 6  Bitcoin rise could leave carbon footprint the ...
# 7  Bitcoin surges higher, narrows gap to record h...
# 8  Stocks surge in risk reversal with yields easi...
# 9  First Insured Bitcoin Fund Opens for Southeast...
#
#                                                 desc  \
# 0  Talia Datt, 25, only invests in companies maki...
# 1  FOMO is all too real, according to a new poll ...
# 2  Select altcoins could rally to new all-time hi...
# 3  A stable funding rate paired with a record-hig...
# 4  Whenever a crypto-bull run is unfolding in the...
# 5  Bitcoin miners are putting as much CO2 into th...
# 6  Research estimates cryptocurrency will consume...
# 7  Bitcoin rose strongly today, on course to gain...
# 8  Investors poured back into the market’s riskie...
# 9  A regulated and insured bitcoin fund has been ...
#
#                         outlet  \
# 0  Australian Financial Review
# 1                      Decrypt
# 2                Cointelegraph
# 3                Cointelegraph
# 4                Ambcrypto.com
# 5                      Newshub
# 6                 The Guardian
# 7                          RTE
# 8              BNNBloomberg.ca
# 9                     CoinDesk
#
#                                                  img  \
# 0  https://static.ffx.io/images/$zoom_0.672%2C$mu...
# 1  https://cdn.decrypt.co/resize/1024/height/512/...
# 2  https://images.cointelegraph.com/images/1200_a...
# 3  https://images.cointelegraph.com/images/1200_a...
# 4  https://ambcrypto.s3.amazonaws.com/wp-content/...
# 5  https://www.newshub.co.nz/home/money/2021/03/b...
# 6  https://i.guim.co.uk/img/media/cd78fc0685ca2ad...
# 7            https://img.rasset.ie/000f092a-1600.jpg
# 8  http://www.bnnbloomberg.ca/polopoly_fs/1.15644...
# 9  https://static.coindesk.com/wp-content/uploads...
#
#                                                  url       publishedAt
# 0  https://www.afr.com/wealth/investing/meet-the-...  2021-03-11 03:33
# 1  https://decrypt.co/60917/investors-missed-bitc...  2021-03-11 00:03
# 2  https://cointelegraph.com/news/price-analysis-...  2021-03-10 22:05
# 3  https://cointelegraph.com/news/3-key-bitcoin-p...  2021-03-10 20:30
# 4  https://ambcrypto.com/bitcoin-its-not-all-abou...  2021-03-10 16:31
# 5  https://www.newshub.co.nz/home/money/2021/03/b...  2021-03-10 16:13
# 6  https://amp.theguardian.com/technology/2021/ma...  2021-03-10 16:00
# 7  https://www.rte.ie/news/business/2021/0309/120...  2021-03-09 17:56
# 8  http://www.bnnbloomberg.ca/asia-set-for-muted-...  2021-03-09 17:03
# 9  https://www.coindesk.com/first-insured-bitcoin...  2021-03-09 14:15
