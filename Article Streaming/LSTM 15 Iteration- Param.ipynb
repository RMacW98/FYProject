# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-4-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    893
# sma      893
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:3].values
valid_set = data2.iloc[650:, 1:3].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.75))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 150, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 32)
# Out:
# Epoch 1/150
# 19/19 [==============================] - 17s 442ms/step - loss: 0.1508 - val_loss: 0.0391
#
# Epoch 00001: val_loss improved from inf to 0.03907, saving model to weights.h5
# Epoch 2/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0530 - val_loss: 0.0399
#
# Epoch 00002: val_loss did not improve from 0.03907
# Epoch 3/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0416 - val_loss: 0.0382
#
# Epoch 00003: val_loss improved from 0.03907 to 0.03819, saving model to weights.h5
# Epoch 4/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0342 - val_loss: 0.0374
#
# Epoch 00004: val_loss improved from 0.03819 to 0.03741, saving model to weights.h5
# Epoch 5/150
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0392 - val_loss: 0.0343
#
# Epoch 00005: val_loss improved from 0.03741 to 0.03430, saving model to weights.h5
# Epoch 6/150
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0347 - val_loss: 0.0324
#
# Epoch 00006: val_loss improved from 0.03430 to 0.03240, saving model to weights.h5
# Epoch 7/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0297 - val_loss: 0.0376
#
# Epoch 00007: val_loss did not improve from 0.03240
# Epoch 8/150
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0295 - val_loss: 0.0347
#
# Epoch 00008: val_loss did not improve from 0.03240
# Epoch 9/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0305 - val_loss: 0.0304
#
# Epoch 00009: val_loss improved from 0.03240 to 0.03038, saving model to weights.h5
# Epoch 10/150
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0286 - val_loss: 0.0295
#
# Epoch 00010: val_loss improved from 0.03038 to 0.02950, saving model to weights.h5
# Epoch 11/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0256 - val_loss: 0.0285
#
# Epoch 00011: val_loss improved from 0.02950 to 0.02848, saving model to weights.h5
# Epoch 12/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0248 - val_loss: 0.0277
#
# Epoch 00012: val_loss improved from 0.02848 to 0.02767, saving model to weights.h5
# Epoch 13/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0235 - val_loss: 0.0267
#
# Epoch 00013: val_loss improved from 0.02767 to 0.02670, saving model to weights.h5
# Epoch 14/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0256 - val_loss: 0.0260
#
# Epoch 00014: val_loss improved from 0.02670 to 0.02597, saving model to weights.h5
# Epoch 15/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0212 - val_loss: 0.0258
#
# Epoch 00015: val_loss improved from 0.02597 to 0.02579, saving model to weights.h5
# Epoch 16/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0226 - val_loss: 0.0266
#
# Epoch 00016: val_loss did not improve from 0.02579
# Epoch 17/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0209 - val_loss: 0.0244
#
# Epoch 00017: val_loss improved from 0.02579 to 0.02443, saving model to weights.h5
# Epoch 18/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0186 - val_loss: 0.0239
#
# Epoch 00018: val_loss improved from 0.02443 to 0.02393, saving model to weights.h5
# Epoch 19/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0211 - val_loss: 0.0214
#
# Epoch 00019: val_loss improved from 0.02393 to 0.02142, saving model to weights.h5
# Epoch 20/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0228 - val_loss: 0.0217
#
# Epoch 00020: val_loss did not improve from 0.02142
# Epoch 21/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0180 - val_loss: 0.0220
#
# Epoch 00021: val_loss did not improve from 0.02142
# Epoch 22/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0207 - val_loss: 0.0210
#
# Epoch 00022: val_loss improved from 0.02142 to 0.02097, saving model to weights.h5
# Epoch 23/150
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0226 - val_loss: 0.0210
#
# Epoch 00023: val_loss improved from 0.02097 to 0.02095, saving model to weights.h5
# Epoch 24/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0183 - val_loss: 0.0239
#
# Epoch 00024: val_loss did not improve from 0.02095
# Epoch 25/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0163 - val_loss: 0.0204
#
# Epoch 00025: val_loss improved from 0.02095 to 0.02043, saving model to weights.h5
# Epoch 26/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0176 - val_loss: 0.0203
#
# Epoch 00026: val_loss improved from 0.02043 to 0.02030, saving model to weights.h5
# Epoch 27/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0191 - val_loss: 0.0187
#
# Epoch 00027: val_loss improved from 0.02030 to 0.01870, saving model to weights.h5
# Epoch 28/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0146 - val_loss: 0.0181
#
# Epoch 00028: val_loss improved from 0.01870 to 0.01810, saving model to weights.h5
# Epoch 29/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0134 - val_loss: 0.0191
#
# Epoch 00029: val_loss did not improve from 0.01810
# Epoch 30/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0137 - val_loss: 0.0176
#
# Epoch 00030: val_loss improved from 0.01810 to 0.01757, saving model to weights.h5
# Epoch 31/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0185 - val_loss: 0.0186
#
# Epoch 00031: val_loss did not improve from 0.01757
# Epoch 32/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0125 - val_loss: 0.0170
#
# Epoch 00032: val_loss improved from 0.01757 to 0.01705, saving model to weights.h5
# Epoch 33/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0140 - val_loss: 0.0193
#
# Epoch 00033: val_loss did not improve from 0.01705
# Epoch 34/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0151 - val_loss: 0.0174
#
# Epoch 00034: val_loss did not improve from 0.01705
# Epoch 35/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0142 - val_loss: 0.0172
#
# Epoch 00035: val_loss did not improve from 0.01705
# Epoch 36/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0133 - val_loss: 0.0166
#
# Epoch 00036: val_loss improved from 0.01705 to 0.01662, saving model to weights.h5
# Epoch 37/150
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0166 - val_loss: 0.0169
#
# Epoch 00037: val_loss did not improve from 0.01662
# Epoch 38/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0165 - val_loss: 0.0180
#
# Epoch 00038: val_loss did not improve from 0.01662
# Epoch 39/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0136 - val_loss: 0.0166
#
# Epoch 00039: val_loss improved from 0.01662 to 0.01658, saving model to weights.h5
# Epoch 40/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0125 - val_loss: 0.0163
#
# Epoch 00040: val_loss improved from 0.01658 to 0.01632, saving model to weights.h5
# Epoch 41/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0118 - val_loss: 0.0174
#
# Epoch 00041: val_loss did not improve from 0.01632
# Epoch 42/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0121 - val_loss: 0.0160
#
# Epoch 00042: val_loss improved from 0.01632 to 0.01603, saving model to weights.h5
# Epoch 43/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0111 - val_loss: 0.0197
#
# Epoch 00043: val_loss did not improve from 0.01603
# Epoch 44/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0133 - val_loss: 0.0163
#
# Epoch 00044: val_loss did not improve from 0.01603
# Epoch 45/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0137 - val_loss: 0.0159
#
# Epoch 00045: val_loss improved from 0.01603 to 0.01593, saving model to weights.h5
# Epoch 46/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0125 - val_loss: 0.0157
#
# Epoch 00046: val_loss improved from 0.01593 to 0.01567, saving model to weights.h5
# Epoch 47/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0111 - val_loss: 0.0157
#
# Epoch 00047: val_loss did not improve from 0.01567
# Epoch 48/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0104 - val_loss: 0.0160
# Epoch 00048: val_loss did not improve from 0.01567
# Epoch 49/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0114 - val_loss: 0.0155
#
# Epoch 00049: val_loss improved from 0.01567 to 0.01546, saving model to weights.h5
# Epoch 50/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0118 - val_loss: 0.0154
#
# Epoch 00050: val_loss improved from 0.01546 to 0.01536, saving model to weights.h5
# Epoch 51/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0114 - val_loss: 0.0163
#
# Epoch 00051: val_loss did not improve from 0.01536
# Epoch 52/150
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0121 - val_loss: 0.0159
#
# Epoch 00052: val_loss did not improve from 0.01536
# Epoch 53/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0119 - val_loss: 0.0159
#
# Epoch 00053: val_loss did not improve from 0.01536
# Epoch 54/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0126 - val_loss: 0.0151
#
# Epoch 00054: val_loss improved from 0.01536 to 0.01511, saving model to weights.h5
# Epoch 55/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0100 - val_loss: 0.0147
#
# Epoch 00055: val_loss improved from 0.01511 to 0.01468, saving model to weights.h5
# Epoch 56/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0117 - val_loss: 0.0147
#
# Epoch 00056: val_loss did not improve from 0.01468
# Epoch 57/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0113 - val_loss: 0.0149
#
# Epoch 00057: val_loss did not improve from 0.01468
# Epoch 58/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0092 - val_loss: 0.0145
#
# Epoch 00058: val_loss improved from 0.01468 to 0.01453, saving model to weights.h5
# Epoch 59/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0118 - val_loss: 0.0150
#
# Epoch 00059: val_loss did not improve from 0.01453
# Epoch 60/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0116 - val_loss: 0.0144
#
# Epoch 00060: val_loss improved from 0.01453 to 0.01443, saving model to weights.h5
# Epoch 61/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0103 - val_loss: 0.0148
#
# Epoch 00061: val_loss did not improve from 0.01443
# Epoch 62/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0093 - val_loss: 0.0141
#
# Epoch 00062: val_loss improved from 0.01443 to 0.01409, saving model to weights.h5
# Epoch 63/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0104 - val_loss: 0.0154
#
# Epoch 00063: val_loss did not improve from 0.01409
# Epoch 64/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0096 - val_loss: 0.0140
#
# Epoch 00064: val_loss improved from 0.01409 to 0.01397, saving model to weights.h5
# Epoch 65/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0095 - val_loss: 0.0137
#
# Epoch 00065: val_loss improved from 0.01397 to 0.01371, saving model to weights.h5
# Epoch 66/150
# 19/19 [==============================] - 1s 70ms/step - loss: 0.0098 - val_loss: 0.0143
#
# Epoch 00066: val_loss did not improve from 0.01371
# Epoch 67/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0101 - val_loss: 0.0141
#
# Epoch 00067: val_loss did not improve from 0.01371
# Epoch 68/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0096 - val_loss: 0.0142
#
# Epoch 00068: val_loss did not improve from 0.01371
# Epoch 69/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0093 - val_loss: 0.0135
#
# Epoch 00069: val_loss improved from 0.01371 to 0.01345, saving model to weights.h5
# Epoch 70/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0089 - val_loss: 0.0132
#
# Epoch 00070: val_loss improved from 0.01345 to 0.01319, saving model to weights.h5
# Epoch 71/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0097 - val_loss: 0.0134
#
# Epoch 00071: val_loss did not improve from 0.01319
# Epoch 72/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0102 - val_loss: 0.0135
#
# Epoch 00072: val_loss did not improve from 0.01319
# Epoch 73/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0124 - val_loss: 0.0154
#
# Epoch 00073: val_loss did not improve from 0.01319
# Epoch 74/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0086 - val_loss: 0.0132
#
# Epoch 00074: val_loss did not improve from 0.01319
# Epoch 75/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0100 - val_loss: 0.0127
#
# Epoch 00075: val_loss improved from 0.01319 to 0.01273, saving model to weights.h5
# Epoch 76/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0105 - val_loss: 0.0128
#
# Epoch 00076: val_loss did not improve from 0.01273
# Epoch 77/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0084 - val_loss: 0.0137
#
# Epoch 00077: val_loss did not improve from 0.01273
# Epoch 78/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0090 - val_loss: 0.0131
#
# Epoch 00078: val_loss did not improve from 0.01273
# Epoch 79/150
# 19/19 [==============================] - 1s 70ms/step - loss: 0.0092 - val_loss: 0.0133
#
# Epoch 00079: val_loss did not improve from 0.01273
# Epoch 80/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0086 - val_loss: 0.0137
#
# Epoch 00080: val_loss did not improve from 0.01273
# Epoch 81/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0093 - val_loss: 0.0130
#
# Epoch 00081: val_loss did not improve from 0.01273
# Epoch 82/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0108 - val_loss: 0.0133
#
# Epoch 00082: val_loss did not improve from 0.01273
# Epoch 83/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0096 - val_loss: 0.0121
#
# Epoch 00083: val_loss improved from 0.01273 to 0.01213, saving model to weights.h5
# Epoch 84/150
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0102 - val_loss: 0.0121
#
# Epoch 00084: val_loss improved from 0.01213 to 0.01207, saving model to weights.h5
# Epoch 85/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0102 - val_loss: 0.0122
#
# Epoch 00085: val_loss did not improve from 0.01207
# Epoch 86/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0090 - val_loss: 0.0118
#
# Epoch 00086: val_loss improved from 0.01207 to 0.01178, saving model to weights.h5
# Epoch 87/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0104 - val_loss: 0.0119
#
# Epoch 00087: val_loss did not improve from 0.01178
# Epoch 88/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0088 - val_loss: 0.0119
#
# Epoch 00088: val_loss did not improve from 0.01178
# Epoch 89/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0079 - val_loss: 0.0119
#
# Epoch 00089: val_loss did not improve from 0.01178
# Epoch 90/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0084 - val_loss: 0.0127
#
# Epoch 00090: val_loss did not improve from 0.01178
# Epoch 91/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0080 - val_loss: 0.0116
#
# Epoch 00091: val_loss improved from 0.01178 to 0.01163, saving model to weights.h5
# Epoch 92/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0075 - val_loss: 0.0121
#
# Epoch 00092: val_loss did not improve from 0.01163
# Epoch 93/150
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0099 - val_loss: 0.0125
#
# Epoch 00093: val_loss did not improve from 0.01163
# Epoch 94/150
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0099 - val_loss: 0.0112
#
# Epoch 00094: val_loss improved from 0.01163 to 0.01121, saving model to weights.h5
# Epoch 95/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0089 - val_loss: 0.0112
#
# Epoch 00095: val_loss did not improve from 0.01121
# Epoch 96/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0081 - val_loss: 0.0111
#
# Epoch 00096: val_loss improved from 0.01121 to 0.01112, saving model to weights.h5
# Epoch 97/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0099 - val_loss: 0.0115
#
# Epoch 00097: val_loss did not improve from 0.01112
# Epoch 98/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0091 - val_loss: 0.0114
#
# Epoch 00098: val_loss did not improve from 0.01112
# Epoch 99/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0077 - val_loss: 0.0109
#
# Epoch 00099: val_loss improved from 0.01112 to 0.01093, saving model to weights.h5
# Epoch 100/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0072 - val_loss: 0.0109
#
# Epoch 00100: val_loss did not improve from 0.01093
# Epoch 101/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0077 - val_loss: 0.0107
#
# Epoch 00101: val_loss improved from 0.01093 to 0.01070, saving model to weights.h5
# Epoch 102/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0089 - val_loss: 0.0118
#
# Epoch 00102: val_loss did not improve from 0.01070
# Epoch 103/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0083 - val_loss: 0.0110
#
# Epoch 00103: val_loss did not improve from 0.01070
# Epoch 104/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0077 - val_loss: 0.0106
#
# Epoch 00104: val_loss improved from 0.01070 to 0.01058, saving model to weights.h5
# Epoch 105/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0068 - val_loss: 0.0104
#
# Epoch 00105: val_loss improved from 0.01058 to 0.01045, saving model to weights.h5
# Epoch 106/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0074 - val_loss: 0.0104
#
# Epoch 00106: val_loss improved from 0.01045 to 0.01041, saving model to weights.h5
# Epoch 107/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0089 - val_loss: 0.0112
#
# Epoch 00107: val_loss did not improve from 0.01041
# Epoch 108/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0079 - val_loss: 0.0102
#
# Epoch 00108: val_loss improved from 0.01041 to 0.01022, saving model to weights.h5
# Epoch 109/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0073 - val_loss: 0.0112
#
# Epoch 00109: val_loss did not improve from 0.01022
# Epoch 110/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0075 - val_loss: 0.0103
#
# Epoch 00110: val_loss did not improve from 0.01022
# Epoch 111/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0100 - val_loss: 0.0106
#
# Epoch 00111: val_loss did not improve from 0.01022
# Epoch 112/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0073 - val_loss: 0.0103
#
# Epoch 00112: val_loss did not improve from 0.01022
# Epoch 113/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0081 - val_loss: 0.0110
#
# Epoch 00113: val_loss did not improve from 0.01022
# Epoch 114/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0082 - val_loss: 0.0111
#
# Epoch 00114: val_loss did not improve from 0.01022
# Epoch 115/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0081 - val_loss: 0.0103
#
# Epoch 00115: val_loss did not improve from 0.01022
# Epoch 116/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0085 - val_loss: 0.0101
#
# Epoch 00116: val_loss improved from 0.01022 to 0.01012, saving model to weights.h5
# Epoch 117/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0073 - val_loss: 0.0108
#
# Epoch 00117: val_loss did not improve from 0.01012
# Epoch 118/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0070 - val_loss: 0.0099
#
# Epoch 00118: val_loss improved from 0.01012 to 0.00986, saving model to weights.h5
# Epoch 119/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0078 - val_loss: 0.0097
#
# Epoch 00119: val_loss improved from 0.00986 to 0.00973, saving model to weights.h5
# Epoch 120/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0072 - val_loss: 0.0105
#
# Epoch 00120: val_loss did not improve from 0.00973
# Epoch 121/150
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0080 - val_loss: 0.0101
#
# Epoch 00121: val_loss did not improve from 0.00973
# Epoch 122/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0069 - val_loss: 0.0100
#
# Epoch 00122: val_loss did not improve from 0.00973
# Epoch 123/150
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0081 - val_loss: 0.0102
#
# Epoch 00123: val_loss did not improve from 0.00973
# Epoch 124/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0070 - val_loss: 0.0098
#
# Epoch 00124: val_loss did not improve from 0.00973
# Epoch 125/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0075 - val_loss: 0.0104
#
# Epoch 00125: val_loss did not improve from 0.00973
# Epoch 126/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0071 - val_loss: 0.0099
#
# Epoch 00126: val_loss did not improve from 0.00973
# Epoch 127/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0083 - val_loss: 0.0097
#
# Epoch 00127: val_loss improved from 0.00973 to 0.00969, saving model to weights.h5
# Epoch 128/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0070 - val_loss: 0.0099
#
# Epoch 00128: val_loss did not improve from 0.00969
# Epoch 129/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0079 - val_loss: 0.0097
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00129: val_loss did not improve from 0.00969
# Epoch 130/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0077 - val_loss: 0.0096
#
# Epoch 00130: val_loss improved from 0.00969 to 0.00965, saving model to weights.h5
# Epoch 131/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0075 - val_loss: 0.0095
#
# Epoch 00131: val_loss improved from 0.00965 to 0.00954, saving model to weights.h5
# Epoch 132/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0073 - val_loss: 0.0096
#
# Epoch 00132: val_loss did not improve from 0.00954
# Epoch 133/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0073 - val_loss: 0.0101
#
# Epoch 00133: val_loss did not improve from 0.00954
# Epoch 134/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0072 - val_loss: 0.0095
#
# Epoch 00134: val_loss improved from 0.00954 to 0.00947, saving model to weights.h5
# Epoch 135/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0061 - val_loss: 0.0095
#
# Epoch 00135: val_loss did not improve from 0.00947
# Epoch 136/150
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0064 - val_loss: 0.0111
#
# Epoch 00136: val_loss did not improve from 0.00947
# Epoch 137/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0078 - val_loss: 0.0097
#
# Epoch 00137: val_loss did not improve from 0.00947
# Epoch 138/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0069 - val_loss: 0.0098
#
# Epoch 00138: val_loss did not improve from 0.00947
# Epoch 139/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0070 - val_loss: 0.0106
#
# Epoch 00139: val_loss did not improve from 0.00947
# Epoch 140/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0065 - val_loss: 0.0092
#
# Epoch 00140: val_loss improved from 0.00947 to 0.00917, saving model to weights.h5
# Epoch 141/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0073 - val_loss: 0.0095
#
# Epoch 00141: val_loss did not improve from 0.00917
# Epoch 142/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0074 - val_loss: 0.0093
#
# Epoch 00142: val_loss did not improve from 0.00917
# Epoch 143/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0063 - val_loss: 0.0095
#
# Epoch 00143: val_loss did not improve from 0.00917
# Epoch 144/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0069 - val_loss: 0.0096
#
# Epoch 00144: val_loss did not improve from 0.00917
# Epoch 145/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0082 - val_loss: 0.0094
#
# Epoch 00145: val_loss did not improve from 0.00917
# Epoch 146/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0068 - val_loss: 0.0093
#
# Epoch 00146: val_loss did not improve from 0.00917
# Epoch 147/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0066 - val_loss: 0.0094
#
# Epoch 00147: val_loss did not improve from 0.00917
# Epoch 148/150
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0070 - val_loss: 0.0093
#
# Epoch 00148: val_loss did not improve from 0.00917
# Epoch 149/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0064 - val_loss: 0.0091
#
# Epoch 00149: val_loss improved from 0.00917 to 0.00914, saving model to weights.h5
# Epoch 150/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0065 - val_loss: 0.0091
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00150: val_loss did not improve from 0.00914

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:3].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 516.6218190263894

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-14-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
