# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    900
# sma      900
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:3].values
valid_set = data2.iloc[650:, 1:3].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.75))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.75))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 150, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 32)
# Out:
# Epoch 1/150
# 19/19 [==============================] - 15s 426ms/step - loss: 0.1815 - val_loss: 0.0631
#
# Epoch 00001: val_loss improved from inf to 0.06314, saving model to weights.h5
# Epoch 2/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0761 - val_loss: 0.0493
#
# Epoch 00002: val_loss improved from 0.06314 to 0.04933, saving model to weights.h5
# Epoch 3/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0617 - val_loss: 0.0445
#
# Epoch 00003: val_loss improved from 0.04933 to 0.04448, saving model to weights.h5
# Epoch 4/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0525 - val_loss: 0.0518
#
# Epoch 00004: val_loss did not improve from 0.04448
# Epoch 5/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0484 - val_loss: 0.0386
#
# Epoch 00005: val_loss improved from 0.04448 to 0.03864, saving model to weights.h5
# Epoch 6/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0450 - val_loss: 0.0402
#
# Epoch 00006: val_loss did not improve from 0.03864
# Epoch 7/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0426 - val_loss: 0.0378
#
# Epoch 00007: val_loss improved from 0.03864 to 0.03778, saving model to weights.h5
# Epoch 8/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0359 - val_loss: 0.0357
#
# Epoch 00008: val_loss improved from 0.03778 to 0.03574, saving model to weights.h5
# Epoch 9/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0382 - val_loss: 0.0336
#
# Epoch 00009: val_loss improved from 0.03574 to 0.03362, saving model to weights.h5
# Epoch 10/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0371 - val_loss: 0.0362
#
# Epoch 00010: val_loss did not improve from 0.03362
# Epoch 11/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0331 - val_loss: 0.0317
#
# Epoch 00011: val_loss improved from 0.03362 to 0.03170, saving model to weights.h5
# Epoch 12/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0277 - val_loss: 0.0296
#
# Epoch 00012: val_loss improved from 0.03170 to 0.02959, saving model to weights.h5
# Epoch 13/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0317 - val_loss: 0.0298
#
# Epoch 00013: val_loss did not improve from 0.02959
# Epoch 14/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0331 - val_loss: 0.0274
#
# Epoch 00014: val_loss improved from 0.02959 to 0.02737, saving model to weights.h5
# Epoch 15/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0237 - val_loss: 0.0253
#
# Epoch 00015: val_loss improved from 0.02737 to 0.02534, saving model to weights.h5
# Epoch 16/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0249 - val_loss: 0.0263
#
# Epoch 00016: val_loss did not improve from 0.02534
# Epoch 17/150
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0243 - val_loss: 0.0268
#
# Epoch 00017: val_loss did not improve from 0.02534
# Epoch 18/150
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0233 - val_loss: 0.0246
#
# Epoch 00018: val_loss improved from 0.02534 to 0.02465, saving model to weights.h5
# Epoch 19/150
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0238 - val_loss: 0.0223
#
# Epoch 00019: val_loss improved from 0.02465 to 0.02228, saving model to weights.h5
# Epoch 20/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0208 - val_loss: 0.0228
#
# Epoch 00020: val_loss did not improve from 0.02228
# Epoch 21/150
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0225 - val_loss: 0.0216
#
# Epoch 00021: val_loss improved from 0.02228 to 0.02157, saving model to weights.h5
# Epoch 22/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0206 - val_loss: 0.0223
#
# Epoch 00022: val_loss did not improve from 0.02157
# Epoch 23/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0182 - val_loss: 0.0225
#
# Epoch 00023: val_loss did not improve from 0.02157
# Epoch 24/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0190 - val_loss: 0.0200
#
# Epoch 00024: val_loss improved from 0.02157 to 0.01996, saving model to weights.h5
# Epoch 25/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0181 - val_loss: 0.0203
#
# Epoch 00025: val_loss did not improve from 0.01996
# Epoch 26/150
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0184 - val_loss: 0.0202
#
# Epoch 00026: val_loss did not improve from 0.01996
# Epoch 27/150
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0157 - val_loss: 0.0195
#
# Epoch 00027: val_loss improved from 0.01996 to 0.01948, saving model to weights.h5
# Epoch 28/150
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0207 - val_loss: 0.0201
#
# Epoch 00028: val_loss did not improve from 0.01948
# Epoch 29/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0157 - val_loss: 0.0184
#
# Epoch 00029: val_loss improved from 0.01948 to 0.01843, saving model to weights.h5
# Epoch 30/150
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0158 - val_loss: 0.0184
#
# Epoch 00030: val_loss improved from 0.01843 to 0.01835, saving model to weights.h5
# Epoch 31/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0167 - val_loss: 0.0187
#
# Epoch 00031: val_loss did not improve from 0.01835
# Epoch 32/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0158 - val_loss: 0.0194
#
# Epoch 00032: val_loss did not improve from 0.01835
# Epoch 33/150
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0157 - val_loss: 0.0181
#
# Epoch 00033: val_loss improved from 0.01835 to 0.01806, saving model to weights.h5
# Epoch 34/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0147 - val_loss: 0.0176
#
# Epoch 00034: val_loss improved from 0.01806 to 0.01756, saving model to weights.h5
# Epoch 35/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0137 - val_loss: 0.0171
#
# Epoch 00035: val_loss improved from 0.01756 to 0.01714, saving model to weights.h5
# Epoch 36/150
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0134 - val_loss: 0.0163
#
# Epoch 00036: val_loss improved from 0.01714 to 0.01633, saving model to weights.h5
# Epoch 37/150
# 19/19 [==============================] - 1s 70ms/step - loss: 0.0138 - val_loss: 0.0161
#
# Epoch 00037: val_loss improved from 0.01633 to 0.01612, saving model to weights.h5
# Epoch 38/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0139 - val_loss: 0.0167
#
# Epoch 00038: val_loss did not improve from 0.01612
# Epoch 39/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0128 - val_loss: 0.0164
#
# Epoch 00039: val_loss did not improve from 0.01612
# Epoch 40/150
# 19/19 [==============================] - 1s 70ms/step - loss: 0.0124 - val_loss: 0.0162
#
# Epoch 00040: val_loss did not improve from 0.01612
# Epoch 41/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0116 - val_loss: 0.0164
#
# Epoch 00041: val_loss did not improve from 0.01612
# Epoch 42/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0127 - val_loss: 0.0158
#
# Epoch 00042: val_loss improved from 0.01612 to 0.01583, saving model to weights.h5
# Epoch 43/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0128 - val_loss: 0.0158
#
# Epoch 00043: val_loss improved from 0.01583 to 0.01576, saving model to weights.h5
# Epoch 44/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0119 - val_loss: 0.0157
#
# Epoch 00044: val_loss improved from 0.01576 to 0.01566, saving model to weights.h5
# Epoch 45/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0115 - val_loss: 0.0158
#
# Epoch 00045: val_loss did not improve from 0.01566
# Epoch 46/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0110 - val_loss: 0.0153
#
# Epoch 00046: val_loss improved from 0.01566 to 0.01525, saving model to weights.h5
# Epoch 47/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0114 - val_loss: 0.0154
#
# Epoch 00047: val_loss did not improve from 0.01525
# Epoch 48/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0115 - val_loss: 0.0147
#
# Epoch 00048: val_loss improved from 0.01525 to 0.01470, saving model to weights.h5
# Epoch 49/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0118 - val_loss: 0.0146
#
# Epoch 00049: val_loss improved from 0.01470 to 0.01461, saving model to weights.h5
# Epoch 50/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0124 - val_loss: 0.0144
#
# Epoch 00050: val_loss improved from 0.01461 to 0.01443, saving model to weights.h5
# Epoch 51/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0099 - val_loss: 0.0151
#
# Epoch 00051: val_loss did not improve from 0.01443
# Epoch 52/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0107 - val_loss: 0.0141
#
# Epoch 00052: val_loss improved from 0.01443 to 0.01409, saving model to weights.h5
# Epoch 53/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0118 - val_loss: 0.0162
#
# Epoch 00053: val_loss did not improve from 0.01409
# Epoch 54/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0120 - val_loss: 0.0141
#
# Epoch 00054: val_loss did not improve from 0.01409
# Epoch 55/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0092 - val_loss: 0.0164
#
# Epoch 00055: val_loss did not improve from 0.01409
# Epoch 56/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0111 - val_loss: 0.0148
#
# Epoch 00056: val_loss did not improve from 0.01409
# Epoch 57/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0109 - val_loss: 0.0135
#
# Epoch 00057: val_loss improved from 0.01409 to 0.01351, saving model to weights.h5
# Epoch 58/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0103 - val_loss: 0.0134
#
# Epoch 00058: val_loss improved from 0.01351 to 0.01341, saving model to weights.h5
# Epoch 59/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0104 - val_loss: 0.0132
#
# Epoch 00059: val_loss improved from 0.01341 to 0.01325, saving model to weights.h5
# Epoch 60/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0098 - val_loss: 0.0138
#
# Epoch 00060: val_loss did not improve from 0.01325
# Epoch 61/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0101 - val_loss: 0.0135
#
# Epoch 00061: val_loss did not improve from 0.01325
# Epoch 62/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0102 - val_loss: 0.0128
#
# Epoch 00062: val_loss improved from 0.01325 to 0.01283, saving model to weights.h5
# Epoch 63/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0095 - val_loss: 0.0126
#
# Epoch 00063: val_loss improved from 0.01283 to 0.01258, saving model to weights.h5
# Epoch 64/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0091 - val_loss: 0.0126
#
# Epoch 00064: val_loss improved from 0.01258 to 0.01256, saving model to weights.h5
# Epoch 65/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0098 - val_loss: 0.0135
#
# Epoch 00065: val_loss did not improve from 0.01256
# Epoch 66/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0097 - val_loss: 0.0128
#
# Epoch 00066: val_loss did not improve from 0.01256
# Epoch 67/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0104 - val_loss: 0.0125
#
# Epoch 00067: val_loss improved from 0.01256 to 0.01246, saving model to weights.h5
# Epoch 68/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0102 - val_loss: 0.0124
#
# Epoch 00068: val_loss improved from 0.01246 to 0.01244, saving model to weights.h5
# Epoch 69/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0089 - val_loss: 0.0122
#
# Epoch 00069: val_loss improved from 0.01244 to 0.01220, saving model to weights.h5
# Epoch 70/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0085 - val_loss: 0.0120
#
# Epoch 00070: val_loss improved from 0.01220 to 0.01197, saving model to weights.h5
# Epoch 71/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0086 - val_loss: 0.0119
#
# Epoch 00071: val_loss improved from 0.01197 to 0.01194, saving model to weights.h5
# Epoch 72/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0089 - val_loss: 0.0127
#
# Epoch 00072: val_loss did not improve from 0.01194
# Epoch 73/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0105 - val_loss: 0.0120
#
# Epoch 00073: val_loss did not improve from 0.01194
# Epoch 74/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0081 - val_loss: 0.0120
#
# Epoch 00074: val_loss did not improve from 0.01194
# Epoch 75/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0098 - val_loss: 0.0118
#
# Epoch 00075: val_loss improved from 0.01194 to 0.01180, saving model to weights.h5
# Epoch 76/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0092 - val_loss: 0.0119
#
# Epoch 00076: val_loss did not improve from 0.01180
# Epoch 77/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0090 - val_loss: 0.0134
#
# Epoch 00077: val_loss did not improve from 0.01180
# Epoch 78/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0105 - val_loss: 0.0115
#
# Epoch 00078: val_loss improved from 0.01180 to 0.01154, saving model to weights.h5
# Epoch 79/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0086 - val_loss: 0.0116
#
# Epoch 00079: val_loss did not improve from 0.01154
# Epoch 80/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0091 - val_loss: 0.0116
#
# Epoch 00080: val_loss did not improve from 0.01154
# Epoch 81/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0094 - val_loss: 0.0113
#
# Epoch 00081: val_loss improved from 0.01154 to 0.01130, saving model to weights.h5
# Epoch 82/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0083 - val_loss: 0.0120
#
# Epoch 00082: val_loss did not improve from 0.01130
# Epoch 83/150
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0098 - val_loss: 0.0119
#
# Epoch 00083: val_loss did not improve from 0.01130
# Epoch 84/150
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0091 - val_loss: 0.0112
#
# Epoch 00084: val_loss improved from 0.01130 to 0.01120, saving model to weights.h5
# Epoch 85/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0094 - val_loss: 0.0111
#
# Epoch 00085: val_loss improved from 0.01120 to 0.01109, saving model to weights.h5
# Epoch 86/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0074 - val_loss: 0.0109
#
# Epoch 00086: val_loss improved from 0.01109 to 0.01093, saving model to weights.h5
# Epoch 87/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0078 - val_loss: 0.0108
#
# Epoch 00087: val_loss improved from 0.01093 to 0.01080, saving model to weights.h5
# Epoch 88/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0087 - val_loss: 0.0108
#
# Epoch 00088: val_loss did not improve from 0.01080
# Epoch 89/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0088 - val_loss: 0.0106
#
# Epoch 00089: val_loss improved from 0.01080 to 0.01062, saving model to weights.h5
# Epoch 90/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0081 - val_loss: 0.0113
#
# Epoch 00090: val_loss did not improve from 0.01062
# Epoch 91/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0081 - val_loss: 0.0108
#
# Epoch 00091: val_loss did not improve from 0.01062
# Epoch 92/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0080 - val_loss: 0.0111
#
# Epoch 00092: val_loss did not improve from 0.01062
# Epoch 93/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0083 - val_loss: 0.0112
#
# Epoch 00093: val_loss did not improve from 0.01062
# Epoch 94/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0076 - val_loss: 0.0105
#
# Epoch 00094: val_loss improved from 0.01062 to 0.01052, saving model to weights.h5
# Epoch 95/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0073 - val_loss: 0.0103
#
# Epoch 00095: val_loss improved from 0.01052 to 0.01035, saving model to weights.h5
# Epoch 96/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0083 - val_loss: 0.0106
#
# Epoch 00096: val_loss did not improve from 0.01035
# Epoch 97/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0109 - val_loss: 0.0108
# Epoch 00097: val_loss did not improve from 0.01035
# Epoch 98/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0081 - val_loss: 0.0107
#
# Epoch 00098: val_loss did not improve from 0.01035
# Epoch 99/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0078 - val_loss: 0.0103
#
# Epoch 00099: val_loss improved from 0.01035 to 0.01031, saving model to weights.h5
# Epoch 100/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0087 - val_loss: 0.0105
#
# Epoch 00100: val_loss did not improve from 0.01031
# Epoch 101/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0076 - val_loss: 0.0107
#
# Epoch 00101: val_loss did not improve from 0.01031
# Epoch 102/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0081 - val_loss: 0.0101
#
# Epoch 00102: val_loss improved from 0.01031 to 0.01013, saving model to weights.h5
# Epoch 103/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0085 - val_loss: 0.0098
#
# Epoch 00103: val_loss improved from 0.01013 to 0.00979, saving model to weights.h5
# Epoch 104/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0079 - val_loss: 0.0104
#
# Epoch 00104: val_loss did not improve from 0.00979
# Epoch 105/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0086 - val_loss: 0.0100
#
# Epoch 00105: val_loss did not improve from 0.00979
# Epoch 106/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0077 - val_loss: 0.0099
#
# Epoch 00106: val_loss did not improve from 0.00979
# Epoch 107/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0079 - val_loss: 0.0101
#
# Epoch 00107: val_loss did not improve from 0.00979
# Epoch 108/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0093 - val_loss: 0.0099
#
# Epoch 00108: val_loss did not improve from 0.00979
# Epoch 109/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0073 - val_loss: 0.0097
#
# Epoch 00109: val_loss improved from 0.00979 to 0.00971, saving model to weights.h5
# Epoch 110/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0068 - val_loss: 0.0102
#
# Epoch 00110: val_loss did not improve from 0.00971
# Epoch 111/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0081 - val_loss: 0.0096
#
# Epoch 00111: val_loss improved from 0.00971 to 0.00963, saving model to weights.h5
# Epoch 112/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0099 - val_loss: 0.0095
#
# Epoch 00112: val_loss improved from 0.00963 to 0.00955, saving model to weights.h5
# Epoch 113/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0065 - val_loss: 0.0097
#
# Epoch 00113: val_loss did not improve from 0.00955
# Epoch 114/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0075 - val_loss: 0.0102
#
# Epoch 00114: val_loss did not improve from 0.00955
# Epoch 115/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0082 - val_loss: 0.0101
#
# Epoch 00115: val_loss did not improve from 0.00955
# Epoch 116/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0081 - val_loss: 0.0102
#
# Epoch 00116: val_loss did not improve from 0.00955
# Epoch 117/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0083 - val_loss: 0.0096
#
# Epoch 00117: val_loss did not improve from 0.00955
# Epoch 118/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0073 - val_loss: 0.0095
#
# Epoch 00118: val_loss improved from 0.00955 to 0.00952, saving model to weights.h5
# Epoch 119/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0075 - val_loss: 0.0099
#
# Epoch 00119: val_loss did not improve from 0.00952
# Epoch 120/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0082 - val_loss: 0.0098
#
# Epoch 00120: val_loss did not improve from 0.00952
# Epoch 121/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0072 - val_loss: 0.0102
#
# Epoch 00121: val_loss did not improve from 0.00952
# Epoch 122/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0078 - val_loss: 0.0105
#
# Epoch 00122: val_loss did not improve from 0.00952
# Epoch 123/150
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0075 - val_loss: 0.0098
#
# Epoch 00123: val_loss did not improve from 0.00952
# Epoch 124/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0084 - val_loss: 0.0097
#
# Epoch 00124: val_loss did not improve from 0.00952
# Epoch 125/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0081 - val_loss: 0.0094
#
# Epoch 00125: val_loss improved from 0.00952 to 0.00937, saving model to weights.h5
# Epoch 126/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0066 - val_loss: 0.0102
#
# Epoch 00126: val_loss did not improve from 0.00937
# Epoch 127/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0084 - val_loss: 0.0091
#
# Epoch 00127: val_loss improved from 0.00937 to 0.00912, saving model to weights.h5
# Epoch 128/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0072 - val_loss: 0.0094
#
# Epoch 00128: val_loss did not improve from 0.00912
# Epoch 129/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0066 - val_loss: 0.0091
#
# Epoch 00129: val_loss did not improve from 0.00912
# Epoch 130/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0064 - val_loss: 0.0092
#
# Epoch 00130: val_loss did not improve from 0.00912
# Epoch 131/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00131: val_loss improved from 0.00912 to 0.00893, saving model to weights.h5
# Epoch 132/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0081 - val_loss: 0.0095
#
# Epoch 00132: val_loss did not improve from 0.00893
# Epoch 133/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0083 - val_loss: 0.0102
#
# Epoch 00133: val_loss did not improve from 0.00893
# Epoch 134/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0071 - val_loss: 0.0089
#
# Epoch 00134: val_loss did not improve from 0.00893
# Epoch 135/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0076 - val_loss: 0.0094
#
# Epoch 00135: val_loss did not improve from 0.00893
# Epoch 136/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0078 - val_loss: 0.0092
#
# Epoch 00136: val_loss did not improve from 0.00893
# Epoch 137/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0072 - val_loss: 0.0090
#
# Epoch 00137: val_loss did not improve from 0.00893
# Epoch 138/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0073 - val_loss: 0.0092
#
# Epoch 00138: val_loss did not improve from 0.00893
# Epoch 139/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0074 - val_loss: 0.0086
#
# Epoch 00139: val_loss improved from 0.00893 to 0.00862, saving model to weights.h5
# Epoch 140/150
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0075 - val_loss: 0.0085
#
# Epoch 00140: val_loss improved from 0.00862 to 0.00851, saving model to weights.h5
# Epoch 141/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0069 - val_loss: 0.0084
#
# Epoch 00141: val_loss improved from 0.00851 to 0.00844, saving model to weights.h5
# Epoch 142/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0078 - val_loss: 0.0085
#
# Epoch 00142: val_loss did not improve from 0.00844
# Epoch 143/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0075 - val_loss: 0.0087
#
# Epoch 00143: val_loss did not improve from 0.00844
# Epoch 144/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0063 - val_loss: 0.0086
#
# Epoch 00144: val_loss did not improve from 0.00844
# Epoch 145/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0076 - val_loss: 0.0091
#
# Epoch 00145: val_loss did not improve from 0.00844
# Epoch 146/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0083 - val_loss: 0.0089
#
# Epoch 00146: val_loss did not improve from 0.00844
# Epoch 147/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0081 - val_loss: 0.0084
#
# Epoch 00147: val_loss improved from 0.00844 to 0.00837, saving model to weights.h5
# Epoch 148/150
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0077 - val_loss: 0.0087
#
# Epoch 00148: val_loss did not improve from 0.00837
# Epoch 149/150
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0068 - val_loss: 0.0092
#
# Epoch 00149: val_loss did not improve from 0.00837
# Epoch 150/150
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0080 - val_loss: 0.0087
#
# Epoch 00150: val_loss did not improve from 0.00837

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:3].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 696.9094015047474

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-17-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
