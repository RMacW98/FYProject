# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data.count()
# Out:
# <ipython-input-27-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
# close    900
# sma      900
# dtype: int64

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:650, 1:2].values
valid_set = data2.iloc[650:, 1:2].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 150, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 256)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 14s 4s/step - loss: 0.2733 - val_loss: 0.1857
#
# Epoch 00001: val_loss improved from inf to 0.18569, saving model to weights.h5
# Epoch 2/150
# 3/3 [==============================] - 1s 239ms/step - loss: 0.1270 - val_loss: 0.0500
#
# Epoch 00002: val_loss improved from 0.18569 to 0.05003, saving model to weights.h5
# Epoch 3/150
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0354 - val_loss: 0.0739
#
# Epoch 00003: val_loss did not improve from 0.05003
# Epoch 4/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0339 - val_loss: 0.0488
#
# Epoch 00004: val_loss improved from 0.05003 to 0.04877, saving model to weights.h5
# Epoch 5/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0291 - val_loss: 0.0578
#
# Epoch 00005: val_loss did not improve from 0.04877
# Epoch 6/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0346 - val_loss: 0.0443
#
# Epoch 00006: val_loss improved from 0.04877 to 0.04432, saving model to weights.h5
# Epoch 7/150
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0202 - val_loss: 0.0462
#
# Epoch 00007: val_loss did not improve from 0.04432
# Epoch 8/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0235 - val_loss: 0.0485
#
# Epoch 00008: val_loss did not improve from 0.04432
# Epoch 9/150
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0219 - val_loss: 0.0398
#
# Epoch 00009: val_loss improved from 0.04432 to 0.03981, saving model to weights.h5
# Epoch 10/150
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0196 - val_loss: 0.0418
#
# Epoch 00010: val_loss did not improve from 0.03981
# Epoch 11/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0218 - val_loss: 0.0393
#
# Epoch 00011: val_loss improved from 0.03981 to 0.03934, saving model to weights.h5
# Epoch 12/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0190 - val_loss: 0.0407
#
# Epoch 00012: val_loss did not improve from 0.03934
# Epoch 13/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0169 - val_loss: 0.0420
#
# Epoch 00013: val_loss did not improve from 0.03934
# Epoch 14/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0166 - val_loss: 0.0377
#
# Epoch 00014: val_loss improved from 0.03934 to 0.03775, saving model to weights.h5
# Epoch 15/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0155 - val_loss: 0.0373
#
# Epoch 00015: val_loss improved from 0.03775 to 0.03730, saving model to weights.h5
# Epoch 16/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0141 - val_loss: 0.0378
#
# Epoch 00016: val_loss did not improve from 0.03730
# Epoch 17/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0131 - val_loss: 0.0436
#
# Epoch 00017: val_loss did not improve from 0.03730
# Epoch 18/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0168 - val_loss: 0.0371
#
# Epoch 00018: val_loss improved from 0.03730 to 0.03715, saving model to weights.h5
# Epoch 19/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0139 - val_loss: 0.0352
#
# Epoch 00019: val_loss improved from 0.03715 to 0.03517, saving model to weights.h5
# Epoch 20/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0149 - val_loss: 0.0353
#
# Epoch 00020: val_loss did not improve from 0.03517
# Epoch 21/150
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0129 - val_loss: 0.0367
#
# Epoch 00021: val_loss did not improve from 0.03517
# Epoch 22/150
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0131 - val_loss: 0.0341
#
# Epoch 00022: val_loss improved from 0.03517 to 0.03405, saving model to weights.h5
# Epoch 23/150
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0131 - val_loss: 0.0319
#
# Epoch 00023: val_loss improved from 0.03405 to 0.03187, saving model to weights.h5
# Epoch 24/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0137 - val_loss: 0.0321
#
# Epoch 00024: val_loss did not improve from 0.03187
# Epoch 25/150
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0127 - val_loss: 0.0316
#
# Epoch 00025: val_loss improved from 0.03187 to 0.03158, saving model to weights.h5
# Epoch 26/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0123 - val_loss: 0.0290
#
# Epoch 00026: val_loss improved from 0.03158 to 0.02898, saving model to weights.h5
# Epoch 27/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0116 - val_loss: 0.0283
#
# Epoch 00027: val_loss improved from 0.02898 to 0.02828, saving model to weights.h5
# Epoch 28/150
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0114 - val_loss: 0.0291
#
# Epoch 00028: val_loss did not improve from 0.02828
# Epoch 29/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0111 - val_loss: 0.0281
#
# Epoch 00029: val_loss improved from 0.02828 to 0.02815, saving model to weights.h5
# Epoch 30/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0117 - val_loss: 0.0270
#
# Epoch 00030: val_loss improved from 0.02815 to 0.02704, saving model to weights.h5
# Epoch 31/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0119 - val_loss: 0.0264
#
# Epoch 00031: val_loss improved from 0.02704 to 0.02644, saving model to weights.h5
# Epoch 32/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0108 - val_loss: 0.0275
#
# Epoch 00032: val_loss did not improve from 0.02644
# Epoch 33/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0115 - val_loss: 0.0261
#
# Epoch 00033: val_loss improved from 0.02644 to 0.02606, saving model to weights.h5
# Epoch 34/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0118 - val_loss: 0.0268
#
# Epoch 00034: val_loss did not improve from 0.02606
# Epoch 35/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0106 - val_loss: 0.0272
#
# Epoch 00035: val_loss did not improve from 0.02606
# Epoch 36/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0103 - val_loss: 0.0251
#
# Epoch 00036: val_loss improved from 0.02606 to 0.02509, saving model to weights.h5
# Epoch 37/150
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0117 - val_loss: 0.0243
#
# Epoch 00037: val_loss improved from 0.02509 to 0.02428, saving model to weights.h5
# Epoch 38/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0116 - val_loss: 0.0245
#
# Epoch 00038: val_loss did not improve from 0.02428
# Epoch 39/150
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0111 - val_loss: 0.0237
#
# Epoch 00039: val_loss improved from 0.02428 to 0.02366, saving model to weights.h5
# Epoch 40/150
# 3/3 [==============================] - 1s 249ms/step - loss: 0.0107 - val_loss: 0.0238
#
# Epoch 00040: val_loss did not improve from 0.02366
# Epoch 41/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0103 - val_loss: 0.0236
#
# Epoch 00041: val_loss improved from 0.02366 to 0.02358, saving model to weights.h5
# Epoch 42/150
# 3/3 [==============================] - 1s 315ms/step - loss: 0.0105 - val_loss: 0.0241
#
# Epoch 00042: val_loss did not improve from 0.02358
# Epoch 43/150
# 3/3 [==============================] - 1s 273ms/step - loss: 0.0108 - val_loss: 0.0248
#
# Epoch 00043: val_loss did not improve from 0.02358
# Epoch 44/150
# 3/3 [==============================] - 1s 267ms/step - loss: 0.0096 - val_loss: 0.0233
#
# Epoch 00044: val_loss improved from 0.02358 to 0.02331, saving model to weights.h5
# Epoch 45/150
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0099 - val_loss: 0.0226
#
# Epoch 00045: val_loss improved from 0.02331 to 0.02262, saving model to weights.h5
# Epoch 46/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0111 - val_loss: 0.0238
#
# Epoch 00046: val_loss did not improve from 0.02262
# Epoch 47/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0104 - val_loss: 0.0232
#
# Epoch 00047: val_loss did not improve from 0.02262
# Epoch 48/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0090 - val_loss: 0.0221
#
# Epoch 00048: val_loss improved from 0.02262 to 0.02213, saving model to weights.h5
# Epoch 49/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0101 - val_loss: 0.0235
# Epoch 00049: val_loss did not improve from 0.02213
# Epoch 50/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0097 - val_loss: 0.0223
#
# Epoch 00050: val_loss did not improve from 0.02213
# Epoch 51/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0097 - val_loss: 0.0213
#
# Epoch 00051: val_loss improved from 0.02213 to 0.02133, saving model to weights.h5
# Epoch 52/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0107 - val_loss: 0.0240
#
# Epoch 00052: val_loss did not improve from 0.02133
# Epoch 53/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0105 - val_loss: 0.0211
#
# Epoch 00053: val_loss improved from 0.02133 to 0.02110, saving model to weights.h5
# Epoch 54/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0098 - val_loss: 0.0223
#
# Epoch 00054: val_loss did not improve from 0.02110
# Epoch 55/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0090 - val_loss: 0.0221
#
# Epoch 00055: val_loss did not improve from 0.02110
# Epoch 56/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0098 - val_loss: 0.0215
#
# Epoch 00056: val_loss did not improve from 0.02110
# Epoch 57/150
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0095 - val_loss: 0.0215
#
# Epoch 00057: val_loss did not improve from 0.02110
# Epoch 58/150
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0094 - val_loss: 0.0214
#
# Epoch 00058: val_loss did not improve from 0.02110
# Epoch 59/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0087 - val_loss: 0.0208
#
# Epoch 00059: val_loss improved from 0.02110 to 0.02085, saving model to weights.h5
# Epoch 60/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0093 - val_loss: 0.0207
#
# Epoch 00060: val_loss improved from 0.02085 to 0.02072, saving model to weights.h5
# Epoch 61/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0095 - val_loss: 0.0205
#
# Epoch 00061: val_loss improved from 0.02072 to 0.02047, saving model to weights.h5
# Epoch 62/150
# 3/3 [==============================] - 1s 249ms/step - loss: 0.0091 - val_loss: 0.0199
#
# Epoch 00062: val_loss improved from 0.02047 to 0.01991, saving model to weights.h5
# Epoch 63/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0088 - val_loss: 0.0198
#
# Epoch 00063: val_loss improved from 0.01991 to 0.01975, saving model to weights.h5
# Epoch 64/150
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0084 - val_loss: 0.0192
#
# Epoch 00064: val_loss improved from 0.01975 to 0.01920, saving model to weights.h5
# Epoch 65/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0092 - val_loss: 0.0189
#
# Epoch 00065: val_loss improved from 0.01920 to 0.01894, saving model to weights.h5
# Epoch 66/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0081 - val_loss: 0.0200
#
# Epoch 00066: val_loss did not improve from 0.01894
# Epoch 67/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0088 - val_loss: 0.0187
#
# Epoch 00067: val_loss improved from 0.01894 to 0.01874, saving model to weights.h5
# Epoch 68/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0087 - val_loss: 0.0192
#
# Epoch 00068: val_loss did not improve from 0.01874
# Epoch 69/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0090 - val_loss: 0.0194
#
# Epoch 00069: val_loss did not improve from 0.01874
# Epoch 70/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0076 - val_loss: 0.0190
#
# Epoch 00070: val_loss did not improve from 0.01874
# Epoch 71/150
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0081 - val_loss: 0.0182
#
# Epoch 00071: val_loss improved from 0.01874 to 0.01824, saving model to weights.h5
# Epoch 72/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0085 - val_loss: 0.0184
#
# Epoch 00072: val_loss did not improve from 0.01824
# Epoch 73/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0086 - val_loss: 0.0182
#
# Epoch 00073: val_loss did not improve from 0.01824
# Epoch 74/150
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0084 - val_loss: 0.0173
#
# Epoch 00074: val_loss improved from 0.01824 to 0.01726, saving model to weights.h5
# Epoch 75/150
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0085 - val_loss: 0.0176
#
# Epoch 00075: val_loss did not improve from 0.01726
# Epoch 76/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0088 - val_loss: 0.0174
#
# Epoch 00076: val_loss did not improve from 0.01726
# Epoch 77/150
# 3/3 [==============================] - 1s 290ms/step - loss: 0.0082 - val_loss: 0.0170
#
# Epoch 00077: val_loss improved from 0.01726 to 0.01699, saving model to weights.h5
# Epoch 78/150
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0078 - val_loss: 0.0202
#
# Epoch 00078: val_loss did not improve from 0.01699
# Epoch 79/150
# 3/3 [==============================] - 1s 275ms/step - loss: 0.0084 - val_loss: 0.0170
#
# Epoch 00079: val_loss improved from 0.01699 to 0.01696, saving model to weights.h5
# Epoch 80/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0086 - val_loss: 0.0169
#
# Epoch 00080: val_loss improved from 0.01696 to 0.01693, saving model to weights.h5
# Epoch 81/150
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0074 - val_loss: 0.0183
#
# Epoch 00081: val_loss did not improve from 0.01693
# Epoch 82/150
# 3/3 [==============================] - 1s 286ms/step - loss: 0.0084 - val_loss: 0.0165
#
# Epoch 00082: val_loss improved from 0.01693 to 0.01654, saving model to weights.h5
# Epoch 83/150
# 3/3 [==============================] - 1s 301ms/step - loss: 0.0080 - val_loss: 0.0176
#
# Epoch 00083: val_loss did not improve from 0.01654
# Epoch 84/150
# 3/3 [==============================] - 1s 289ms/step - loss: 0.0078 - val_loss: 0.0161
#
# Epoch 00084: val_loss improved from 0.01654 to 0.01614, saving model to weights.h5
# Epoch 85/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0071 - val_loss: 0.0161
#
# Epoch 00085: val_loss improved from 0.01614 to 0.01606, saving model to weights.h5
# Epoch 86/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0074 - val_loss: 0.0159
#
# Epoch 00086: val_loss improved from 0.01606 to 0.01586, saving model to weights.h5
# Epoch 87/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0066 - val_loss: 0.0155
#
# Epoch 00087: val_loss improved from 0.01586 to 0.01552, saving model to weights.h5
# Epoch 88/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0081 - val_loss: 0.0158
#
# Epoch 00088: val_loss did not improve from 0.01552
# Epoch 89/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0065 - val_loss: 0.0152
#
# Epoch 00089: val_loss improved from 0.01552 to 0.01524, saving model to weights.h5
# Epoch 90/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0077 - val_loss: 0.0163
#
# Epoch 00090: val_loss did not improve from 0.01524
# Epoch 91/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0070 - val_loss: 0.0151
#
# Epoch 00091: val_loss improved from 0.01524 to 0.01509, saving model to weights.h5
# Epoch 92/150
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0070 - val_loss: 0.0153
#
# Epoch 00092: val_loss did not improve from 0.01509
# Epoch 93/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0073 - val_loss: 0.0154
#
# Epoch 00093: val_loss did not improve from 0.01509
# Epoch 94/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0072 - val_loss: 0.0151
#
# Epoch 00094: val_loss improved from 0.01509 to 0.01507, saving model to weights.h5
# Epoch 95/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0070 - val_loss: 0.0159
#
# Epoch 00095: val_loss did not improve from 0.01507
# Epoch 96/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0071 - val_loss: 0.0153
#
# Epoch 00096: val_loss did not improve from 0.01507
# Epoch 97/150
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0073 - val_loss: 0.0162
#
# Epoch 00097: val_loss did not improve from 0.01507
# Epoch 98/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0066 - val_loss: 0.0153
#
# Epoch 00098: val_loss did not improve from 0.01507
# Epoch 99/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0066 - val_loss: 0.0150
#
# Epoch 00099: val_loss improved from 0.01507 to 0.01501, saving model to weights.h5
# Epoch 100/150
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0066 - val_loss: 0.0157
#
# Epoch 00100: val_loss did not improve from 0.01501
# Epoch 101/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0070 - val_loss: 0.0151
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00101: val_loss did not improve from 0.01501
# Epoch 102/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0070 - val_loss: 0.0148
#
# Epoch 00102: val_loss improved from 0.01501 to 0.01482, saving model to weights.h5
# Epoch 103/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0066 - val_loss: 0.0147
#
# Epoch 00103: val_loss improved from 0.01482 to 0.01472, saving model to weights.h5
# Epoch 104/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0060 - val_loss: 0.0162
#
# Epoch 00104: val_loss did not improve from 0.01472
# Epoch 105/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0068 - val_loss: 0.0145
#
# Epoch 00105: val_loss improved from 0.01472 to 0.01454, saving model to weights.h5
# Epoch 106/150
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0067 - val_loss: 0.0143
#
# Epoch 00106: val_loss improved from 0.01454 to 0.01433, saving model to weights.h5
# Epoch 107/150
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0067 - val_loss: 0.0149
#
# Epoch 00107: val_loss did not improve from 0.01433
# Epoch 108/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0062 - val_loss: 0.0149
#
# Epoch 00108: val_loss did not improve from 0.01433
# Epoch 109/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0061 - val_loss: 0.0142
#
# Epoch 00109: val_loss improved from 0.01433 to 0.01416, saving model to weights.h5
# Epoch 110/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0069 - val_loss: 0.0141
#
# Epoch 00110: val_loss improved from 0.01416 to 0.01406, saving model to weights.h5
# Epoch 111/150
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0064 - val_loss: 0.0153
#
# Epoch 00111: val_loss did not improve from 0.01406
# Epoch 112/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0066 - val_loss: 0.0142
#
# Epoch 00112: val_loss did not improve from 0.01406
# Epoch 113/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0060 - val_loss: 0.0140
#
# Epoch 00113: val_loss improved from 0.01406 to 0.01396, saving model to weights.h5
# Epoch 114/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0062 - val_loss: 0.0141
#
# Epoch 00114: val_loss did not improve from 0.01396
# Epoch 115/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0066 - val_loss: 0.0150
#
# Epoch 00115: val_loss did not improve from 0.01396
# Epoch 116/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0070 - val_loss: 0.0140
#
# Epoch 00116: val_loss did not improve from 0.01396
# Epoch 117/150
# 3/3 [==============================] - 1s 275ms/step - loss: 0.0063 - val_loss: 0.0139
#
# Epoch 00117: val_loss improved from 0.01396 to 0.01386, saving model to weights.h5
# Epoch 118/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0068 - val_loss: 0.0141
#
# Epoch 00118: val_loss did not improve from 0.01386
# Epoch 119/150
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0061 - val_loss: 0.0141
#
# Epoch 00119: val_loss did not improve from 0.01386
# Epoch 120/150
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0062 - val_loss: 0.0138
#
# Epoch 00120: val_loss improved from 0.01386 to 0.01375, saving model to weights.h5
# Epoch 121/150
# 3/3 [==============================] - 1s 269ms/step - loss: 0.0060 - val_loss: 0.0141
#
# Epoch 00121: val_loss did not improve from 0.01375
# Epoch 122/150
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0065 - val_loss: 0.0140
#
# Epoch 00122: val_loss did not improve from 0.01375
# Epoch 123/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0065 - val_loss: 0.0137
#
# Epoch 00123: val_loss improved from 0.01375 to 0.01369, saving model to weights.h5
# Epoch 124/150
# 3/3 [==============================] - 1s 256ms/step - loss: 0.0061 - val_loss: 0.0137
#
# Epoch 00124: val_loss improved from 0.01369 to 0.01366, saving model to weights.h5
# Epoch 125/150
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0061 - val_loss: 0.0142
#
# Epoch 00125: val_loss did not improve from 0.01366
# Epoch 126/150
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0057 - val_loss: 0.0140
#
# Epoch 00126: val_loss did not improve from 0.01366
# Epoch 127/150
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0065 - val_loss: 0.0134
#
# Epoch 00127: val_loss improved from 0.01366 to 0.01339, saving model to weights.h5
# Epoch 128/150
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0066 - val_loss: 0.0141
#
# Epoch 00128: val_loss did not improve from 0.01339
# Epoch 129/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0057 - val_loss: 0.0143
#
# Epoch 00129: val_loss did not improve from 0.01339
# Epoch 130/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0061 - val_loss: 0.0133
#
# Epoch 00130: val_loss improved from 0.01339 to 0.01328, saving model to weights.h5
# Epoch 131/150
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0067 - val_loss: 0.0133
#
# Epoch 00131: val_loss did not improve from 0.01328
# Epoch 132/150
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0063 - val_loss: 0.0136
#
# Epoch 00132: val_loss did not improve from 0.01328
# Epoch 133/150
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0060 - val_loss: 0.0130
#
# Epoch 00133: val_loss improved from 0.01328 to 0.01305, saving model to weights.h5
# Epoch 134/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0057 - val_loss: 0.0133
#
# Epoch 00134: val_loss did not improve from 0.01305
# Epoch 135/150
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0064 - val_loss: 0.0136
#
# Epoch 00135: val_loss did not improve from 0.01305
# Epoch 136/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0059 - val_loss: 0.0129
#
# Epoch 00136: val_loss improved from 0.01305 to 0.01289, saving model to weights.h5
# Epoch 137/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0057 - val_loss: 0.0130
#
# Epoch 00137: val_loss did not improve from 0.01289
# Epoch 138/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0061 - val_loss: 0.0138
#
# Epoch 00138: val_loss did not improve from 0.01289
# Epoch 139/150
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0065 - val_loss: 0.0129
#
# Epoch 00139: val_loss did not improve from 0.01289
# Epoch 140/150
# 3/3 [==============================] - 1s 264ms/step - loss: 0.0061 - val_loss: 0.0131
#
# Epoch 00140: val_loss did not improve from 0.01289
# Epoch 141/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0055 - val_loss: 0.0131
#
# Epoch 00141: val_loss did not improve from 0.01289
# Epoch 142/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0055 - val_loss: 0.0130
#
# Epoch 00142: val_loss did not improve from 0.01289
# Epoch 143/150
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0058 - val_loss: 0.0131
#
# Epoch 00143: val_loss did not improve from 0.01289
# Epoch 144/150
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0061 - val_loss: 0.0128
#
# Epoch 00144: val_loss improved from 0.01289 to 0.01284, saving model to weights.h5
# Epoch 145/150
# 3/3 [==============================] - 1s 276ms/step - loss: 0.0062 - val_loss: 0.0142
#
# Epoch 00145: val_loss did not improve from 0.01284
# Epoch 146/150
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0059 - val_loss: 0.0131
#
# Epoch 00146: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00146: val_loss did not improve from 0.01284
# Epoch 147/150
# 3/3 [==============================] - 1s 277ms/step - loss: 0.0053 - val_loss: 0.0129
#
# Epoch 00147: val_loss did not improve from 0.01284
# Epoch 148/150
# 3/3 [==============================] - 1s 273ms/step - loss: 0.0060 - val_loss: 0.0130
#
# Epoch 00148: val_loss did not improve from 0.01284
# Epoch 149/150
# 3/3 [==============================] - 1s 280ms/step - loss: 0.0062 - val_loss: 0.0134
#
# Epoch 00149: val_loss did not improve from 0.01284
# Epoch 150/150
# 3/3 [==============================] - 1s 270ms/step - loss: 0.0060 - val_loss: 0.0132
#
# Epoch 00150: val_loss did not improve from 0.01284

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:2].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-2]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 762.3750794799813

# %%
#for plotting
train = data2[:650]
valid = data2[650:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-37-0930cda9a7cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
