# %%
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, timedelta
import shrimpy
import psycopg2

# %%
class DatabaseClient:
    """
    Functionality for inserting and reading from the database
    """

    def __init__(self):
        # Connect to db
        self.con = psycopg2.connect(
            host='localhost',
            database='postgres',
            user='postgres',
            password='postgres'
        )
        self.article_table = pd.DataFrame()

    def read_db(self):
        cur = self.con.cursor()

        cur.execute("SELECT timestamp, comp_sentiment, sma, ema FROM sent_values WHERE timestamp > '2021-01-26 15:00:00'::timestamp;")

        rows = cur.fetchall()

        self.article_table = pd.DataFrame(data=rows, columns=['timestamp','compound','sma','ema'])


        return self.article_table

# %%
def get_latest_prices(trading_symbol):
    public_key = '12326758a39a720e15d064cab3c1f0a9332d107de453bd41926bb3acd565059e'
    secret_key = '6991cf4c9b518293429db0df6085d1731074bed8abccd7f0279a52fac5b0c1a8a2f6d28e11a50fbb1c6575d1407e637f9ad7c73fbddfa87c5d418fd58971f829'
    
    client = shrimpy.ShrimpyApiClient(public_key, secret_key)
        
    # get the candles for historical values
    candles = client.get_candles(
        'binance',  # exchange
        trading_symbol,      # base_trading_symbol
        'USDT',      # quote_trading_symbol
        '1h'       # interval
    )
        
    # Set the dataframe between these two dates
    tomorrows_date = (datetime.today() - timedelta(hours=1)).strftime("%Y-%m-%d %H:00")
    tomorrows_date = (datetime.today()).strftime("%Y-%m-%d %H:00")
    starting_date = '2021-01-25 02:00:00'

    # Put pulled cryptocurrency values into a dataframe and set dates
    prices_df = pd.DataFrame(candles)
    prices_df['time'] = pd.to_datetime(prices_df['time'], infer_datetime_format=True).dt.tz_localize(None)

    latest_prices = prices_df[(prices_df['time'] > starting_date) & (prices_df['time'] <tomorrows_date)]
    latest_prices['close'] = latest_prices['close'].astype('float64')

    return latest_prices

# %%
database_client = DatabaseClient()
df = database_client.read_db()
df.index = df.timestamp
df = df.iloc[:-1]

data = get_latest_prices('BTC')
data.index = data.time
data = data.iloc[:-4]

dataset_train = data.join(df, lsuffix=data.index, rsuffix=df.index)

dataset_train = dataset_train[['close', 'sma']]
dataset_train = dataset_train.dropna()
stk_data = dataset_train.astype('float')

stk_data
# Out:
# <ipython-input-3-b1d27c6bb073>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_prices['close'] = latest_prices['close'].astype('float64')
#                         close     sma
# time
# 2021-02-07 21:00:00  38530.33  0.2386
# 2021-02-07 22:00:00  38797.02  0.2463
# 2021-02-07 23:00:00  38795.69  0.2555
# 2021-02-08 00:00:00  38725.40  0.2290
# 2021-02-08 01:00:00  38521.72  0.2290
# ...                       ...     ...
# 2021-03-21 03:00:00  57790.00 -0.6158
# 2021-03-21 04:00:00  56909.83 -0.5980
# 2021-03-21 05:00:00  57129.99 -0.5980
# 2021-03-21 06:00:00  57047.98 -0.5980
# 2021-03-21 07:00:00  56972.68 -0.5980
#
# [918 rows x 2 columns]

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Close'])
data2['Date'] = stk_data['Date']
data2['Close'] = stk_data['close']
data2['SMA'] = stk_data['sma']

train_set = data2.iloc[:850, 1:2].values
valid_set = data2.iloc[850:, 1:2].values

sc_train = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc_train.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, len(train_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

sc_valid = MinMaxScaler(feature_range = (0, 1))
valid_set_scaled = sc_valid.fit_transform(valid_set)
X_valid = []
y_valid = []
for i in range(60, len(valid_set)):
    X_valid.append(valid_set_scaled[i-60:i, 0])
    y_valid.append(valid_set_scaled[i, 0]) 
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 10))

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

#es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = regressor.fit(X_train, y_train, epochs = 150, callbacks=[rlr, mcp, tb], validation_data=(X_valid, y_valid), batch_size = 1)
# Out:
# Epoch 1/150
# 790/790 [==============================] - 43s 47ms/step - loss: 0.0015 - val_loss: 0.0247
#
# Epoch 00001: val_loss improved from inf to 0.02468, saving model to weights.h5
# Epoch 2/150
# 790/790 [==============================] - 32s 41ms/step - loss: 0.0014 - val_loss: 0.0233
#
# Epoch 00002: val_loss improved from 0.02468 to 0.02332, saving model to weights.h5
# Epoch 3/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0014 - val_loss: 0.0281
#
# Epoch 00003: val_loss did not improve from 0.02332
# Epoch 4/150
# 790/790 [==============================] - 31s 39ms/step - loss: 0.0014 - val_loss: 0.0278
#
# Epoch 00004: val_loss did not improve from 0.02332
# Epoch 5/150
# 790/790 [==============================] - 31s 39ms/step - loss: 0.0013 - val_loss: 0.0396
#
# Epoch 00005: val_loss did not improve from 0.02332
# Epoch 6/150
# 790/790 [==============================] - 31s 39ms/step - loss: 0.0016 - val_loss: 0.0246
#
# Epoch 00006: val_loss did not improve from 0.02332
# Epoch 7/150
# 790/790 [==============================] - 31s 40ms/step - loss: 0.0013 - val_loss: 0.0289
#
# Epoch 00007: val_loss did not improve from 0.02332
# Epoch 8/150
# 790/790 [==============================] - 31s 39ms/step - loss: 0.0014 - val_loss: 0.0304
#
# Epoch 00008: val_loss did not improve from 0.02332
# Epoch 9/150
# 790/790 [==============================] - 31s 40ms/step - loss: 0.0016 - val_loss: 0.0280
#
# Epoch 00009: val_loss did not improve from 0.02332
# Epoch 10/150
# 790/790 [==============================] - 31s 40ms/step - loss: 0.0011 - val_loss: 0.0221
#
# Epoch 00010: val_loss improved from 0.02332 to 0.02207, saving model to weights.h5
# Epoch 11/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0014 - val_loss: 0.0231
#
# Epoch 00011: val_loss did not improve from 0.02207
# Epoch 12/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0015 - val_loss: 0.0338
#
# Epoch 00012: val_loss did not improve from 0.02207
# Epoch 13/150
# 790/790 [==============================] - 32s 41ms/step - loss: 0.0015 - val_loss: 0.0305
#
# Epoch 00013: val_loss did not improve from 0.02207
# Epoch 14/150
# 790/790 [==============================] - 32s 41ms/step - loss: 0.0013 - val_loss: 0.0296
#
# Epoch 00014: val_loss did not improve from 0.02207
# Epoch 15/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0014 - val_loss: 0.0346
#
# Epoch 00015: val_loss did not improve from 0.02207
# Epoch 16/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0011 - val_loss: 0.0364
#
# Epoch 00016: val_loss did not improve from 0.02207
# Epoch 17/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0013 - val_loss: 0.0269
#
# Epoch 00017: val_loss did not improve from 0.02207
# Epoch 18/150
# 790/790 [==============================] - 32s 41ms/step - loss: 0.0014 - val_loss: 0.0239
#
# Epoch 00018: val_loss did not improve from 0.02207
# Epoch 19/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0012 - val_loss: 0.0393
#
# Epoch 00019: val_loss did not improve from 0.02207
# Epoch 20/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0015 - val_loss: 0.0405
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.02207
# Epoch 21/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0011 - val_loss: 0.0320
#
# Epoch 00021: val_loss did not improve from 0.02207
# Epoch 22/150
# 790/790 [==============================] - 32s 40ms/step - loss: 0.0013 - val_loss: 0.0328
#
# Epoch 00022: val_loss did not improve from 0.02207
# Epoch 23/150
# 790/790 [==============================] - 32s 40ms/step - loss: 9.9759e-04 - val_loss: 0.0297
#
# Epoch 00023: val_loss did not improve from 0.02207
# Epoch 24/150
# 790/790 [==============================] - 33s 41ms/step - loss: 0.0010 - val_loss: 0.0312
#
# Epoch 00024: val_loss did not improve from 0.02207
# Epoch 25/150
# 790/790 [==============================] - 33s 41ms/step - loss: 0.0011 - val_loss: 0.0366
#
# Epoch 00025: val_loss did not improve from 0.02207
# Epoch 26/150
# 790/790 [==============================] - 33s 41ms/step - loss: 0.0010 - val_loss: 0.0372
#
# Epoch 00026: val_loss did not improve from 0.02207
# Epoch 27/150
# 790/790 [==============================] - 33s 41ms/step - loss: 9.3679e-04 - val_loss: 0.0301
#
# Epoch 00027: val_loss did not improve from 0.02207
# Epoch 28/150
# 790/790 [==============================] - 33s 41ms/step - loss: 0.0011 - val_loss: 0.0313
#
# Epoch 00028: val_loss did not improve from 0.02207
# Epoch 29/150
# 790/790 [==============================] - 33s 41ms/step - loss: 0.0011 - val_loss: 0.0300
#
# Epoch 00029: val_loss did not improve from 0.02207
# Epoch 30/150
# 790/790 [==============================] - 33s 41ms/step - loss: 0.0011 - val_loss: 0.0309
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.02207
# Epoch 31/150
# 790/790 [==============================] - 33s 41ms/step - loss: 9.0751e-04 - val_loss: 0.0331
#
# Epoch 00031: val_loss did not improve from 0.02207
# Epoch 32/150
# 790/790 [==============================] - 32s 41ms/step - loss: 0.0011 - val_loss: 0.0359
#
# Epoch 00032: val_loss did not improve from 0.02207
# Epoch 33/150
# 790/790 [==============================] - 32s 41ms/step - loss: 9.5993e-04 - val_loss: 0.0285
#
# Epoch 00033: val_loss did not improve from 0.02207
# Epoch 34/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.3119e-04 - val_loss: 0.0354
#
# Epoch 00034: val_loss did not improve from 0.02207
# Epoch 35/150
# 790/790 [==============================] - 33s 41ms/step - loss: 9.5906e-04 - val_loss: 0.0356
#
# Epoch 00035: val_loss did not improve from 0.02207
# Epoch 36/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.8522e-04 - val_loss: 0.0315
#
# Epoch 00036: val_loss did not improve from 0.02207
# Epoch 37/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.9542e-04 - val_loss: 0.0361
#
# Epoch 00037: val_loss did not improve from 0.02207
# Epoch 38/150
# 790/790 [==============================] - 33s 41ms/step - loss: 9.2165e-04 - val_loss: 0.0332
#
# Epoch 00038: val_loss did not improve from 0.02207
# Epoch 39/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.6814e-04 - val_loss: 0.0296
#
# Epoch 00039: val_loss did not improve from 0.02207
# Epoch 40/150
# 790/790 [==============================] - 33s 41ms/step - loss: 9.6765e-04 - val_loss: 0.0307
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00040: val_loss did not improve from 0.02207
# Epoch 41/150
# 790/790 [==============================] - 33s 41ms/step - loss: 9.3941e-04 - val_loss: 0.0320
#
# Epoch 00041: val_loss did not improve from 0.02207
# Epoch 42/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.1768e-04 - val_loss: 0.0295
#
# Epoch 00042: val_loss did not improve from 0.02207
# Epoch 43/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.5245e-04 - val_loss: 0.0327
#
# Epoch 00043: val_loss did not improve from 0.02207
# Epoch 44/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.1272e-04 - val_loss: 0.0316
#
# Epoch 00044: val_loss did not improve from 0.02207
# Epoch 45/150
# 790/790 [==============================] - 32s 41ms/step - loss: 9.1343e-04 - val_loss: 0.0301
#
# Epoch 00045: val_loss did not improve from 0.02207
# Epoch 46/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.4184e-04 - val_loss: 0.0276
#
# Epoch 00046: val_loss did not improve from 0.02207
# Epoch 47/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.5204e-04 - val_loss: 0.0310
#
# Epoch 00047: val_loss did not improve from 0.02207
# Epoch 48/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.5830e-04 - val_loss: 0.0300
#
# Epoch 00048: val_loss did not improve from 0.02207
# Epoch 49/150
# 790/790 [==============================] - 33s 41ms/step - loss: 8.9343e-04 - val_loss: 0.0308
#
# Epoch 00049: val_loss did not improve from 0.02207
# Epoch 50/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.7233e-04 - val_loss: 0.0320
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00050: val_loss did not improve from 0.02207
# Epoch 51/150
# 790/790 [==============================] - 32s 41ms/step - loss: 8.3261e-04 - val_loss: 0.0324
#
# Epoch 00051: val_loss did not improve from 0.02207
# Epoch 52/150
# 790/790 [==============================] - 32s 41ms/step - loss: 7.1466e-04 - val_loss: 0.0304
#
# Epoch 00052: val_loss did not improve from 0.02207
# Epoch 53/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.2414e-04 - val_loss: 0.0321
#
# Epoch 00053: val_loss did not improve from 0.02207
# Epoch 54/150
# 790/790 [==============================] - 33s 42ms/step - loss: 9.3870e-04 - val_loss: 0.0314
#
# Epoch 00054: val_loss did not improve from 0.02207
# Epoch 55/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.5385e-04 - val_loss: 0.0313
#
# Epoch 00055: val_loss did not improve from 0.02207
# Epoch 56/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0636e-04 - val_loss: 0.0300
#
# Epoch 00056: val_loss did not improve from 0.02207
# Epoch 57/150
# 790/790 [==============================] - 33s 42ms/step - loss: 9.1667e-04 - val_loss: 0.0329
#
# Epoch 00057: val_loss did not improve from 0.02207
# Epoch 58/150
# 790/790 [==============================] - 34s 43ms/step - loss: 8.6475e-04 - val_loss: 0.0333
#
# Epoch 00058: val_loss did not improve from 0.02207
# Epoch 59/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6512e-04 - val_loss: 0.0305
#
# Epoch 00059: val_loss did not improve from 0.02207
# Epoch 60/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.3739e-04 - val_loss: 0.0296
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00060: val_loss did not improve from 0.02207
# Epoch 61/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.3604e-04 - val_loss: 0.0322
#
# Epoch 00061: val_loss did not improve from 0.02207
# Epoch 62/150
# 790/790 [==============================] - 34s 43ms/step - loss: 8.4734e-04 - val_loss: 0.0322
#
# Epoch 00062: val_loss did not improve from 0.02207
# Epoch 63/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.9498e-04 - val_loss: 0.0311
#
# Epoch 00063: val_loss did not improve from 0.02207
# Epoch 64/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0588e-04 - val_loss: 0.0316
#
# Epoch 00064: val_loss did not improve from 0.02207
# Epoch 65/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.9387e-04 - val_loss: 0.0329
#
# Epoch 00065: val_loss did not improve from 0.02207
# Epoch 66/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.4192e-04 - val_loss: 0.0315
#
# Epoch 00066: val_loss did not improve from 0.02207
# Epoch 67/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6004e-04 - val_loss: 0.0302
#
# Epoch 00067: val_loss did not improve from 0.02207
# Epoch 68/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1360e-04 - val_loss: 0.0308
#
# Epoch 00068: val_loss did not improve from 0.02207
# Epoch 69/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6648e-04 - val_loss: 0.0314
#
# Epoch 00069: val_loss did not improve from 0.02207
# Epoch 70/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.0781e-04 - val_loss: 0.0326
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00070: val_loss did not improve from 0.02207
# Epoch 71/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.3101e-04 - val_loss: 0.0320
#
# Epoch 00071: val_loss did not improve from 0.02207
# Epoch 72/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1645e-04 - val_loss: 0.0315
#
# Epoch 00072: val_loss did not improve from 0.02207
# Epoch 73/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.4975e-04 - val_loss: 0.0316
#
# Epoch 00073: val_loss did not improve from 0.02207
# Epoch 74/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.2242e-04 - val_loss: 0.0313
#
# Epoch 00074: val_loss did not improve from 0.02207
# Epoch 75/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0954e-04 - val_loss: 0.0315
#
# Epoch 00075: val_loss did not improve from 0.02207
# Epoch 76/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.5580e-04 - val_loss: 0.0324
#
# Epoch 00076: val_loss did not improve from 0.02207
# Epoch 77/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1843e-04 - val_loss: 0.0323
#
# Epoch 00077: val_loss did not improve from 0.02207
# Epoch 78/150
# 790/790 [==============================] - 34s 42ms/step - loss: 8.9380e-04 - val_loss: 0.0319
#
# Epoch 00078: val_loss did not improve from 0.02207
# Epoch 79/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.5053e-04 - val_loss: 0.0315
#
# Epoch 00079: val_loss did not improve from 0.02207
# Epoch 80/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.7844e-04 - val_loss: 0.0312
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00080: val_loss did not improve from 0.02207
# Epoch 81/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.8103e-04 - val_loss: 0.0317
#
# Epoch 00081: val_loss did not improve from 0.02207
# Epoch 82/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.8292e-04 - val_loss: 0.0317
#
# Epoch 00082: val_loss did not improve from 0.02207
# Epoch 83/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.7714e-04 - val_loss: 0.0315
#
# Epoch 00083: val_loss did not improve from 0.02207
# Epoch 84/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.5026e-04 - val_loss: 0.0314
#
# Epoch 00084: val_loss did not improve from 0.02207
# Epoch 85/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.8028e-04 - val_loss: 0.0317
#
# Epoch 00085: val_loss did not improve from 0.02207
# Epoch 86/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.4178e-04 - val_loss: 0.0315
#
# Epoch 00086: val_loss did not improve from 0.02207
# Epoch 87/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.8260e-04 - val_loss: 0.0313
#
# Epoch 00087: val_loss did not improve from 0.02207
# Epoch 88/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.7297e-04 - val_loss: 0.0317
#
# Epoch 00088: val_loss did not improve from 0.02207
# Epoch 89/150
# 790/790 [==============================] - 33s 42ms/step - loss: 9.6945e-04 - val_loss: 0.0319
#
# Epoch 00089: val_loss did not improve from 0.02207
# Epoch 90/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.6273e-04 - val_loss: 0.0317
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00090: val_loss did not improve from 0.02207
# Epoch 91/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6916e-04 - val_loss: 0.0315
#
# Epoch 00091: val_loss did not improve from 0.02207
# Epoch 92/150
# 790/790 [==============================] - 34s 43ms/step - loss: 7.6515e-04 - val_loss: 0.0316
#
# Epoch 00092: val_loss did not improve from 0.02207
# Epoch 93/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0814e-04 - val_loss: 0.0316
#
# Epoch 00093: val_loss did not improve from 0.02207
# Epoch 94/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.8663e-04 - val_loss: 0.0316
#
# Epoch 00094: val_loss did not improve from 0.02207
# Epoch 95/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0967e-04 - val_loss: 0.0317
#
# Epoch 00095: val_loss did not improve from 0.02207
# Epoch 96/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.9710e-04 - val_loss: 0.0319
#
# Epoch 00096: val_loss did not improve from 0.02207
# Epoch 97/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6518e-04 - val_loss: 0.0319
#
# Epoch 00097: val_loss did not improve from 0.02207
# Epoch 98/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1794e-04 - val_loss: 0.0316
#
# Epoch 00098: val_loss did not improve from 0.02207
# Epoch 99/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6796e-04 - val_loss: 0.0318
#
# Epoch 00099: val_loss did not improve from 0.02207
# Epoch 100/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.1074e-04 - val_loss: 0.0317
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00100: val_loss did not improve from 0.02207
# Epoch 101/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.5437e-04 - val_loss: 0.0318
#
# Epoch 00101: val_loss did not improve from 0.02207
# Epoch 102/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.5332e-04 - val_loss: 0.0316
#
# Epoch 00102: val_loss did not improve from 0.02207
# Epoch 103/150
# 790/790 [==============================] - 33s 41ms/step - loss: 7.5128e-04 - val_loss: 0.0315
#
# Epoch 00103: val_loss did not improve from 0.02207
# Epoch 104/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.4785e-04 - val_loss: 0.0315
#
# Epoch 00104: val_loss did not improve from 0.02207
# Epoch 105/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.2429e-04 - val_loss: 0.0315
#
# Epoch 00105: val_loss did not improve from 0.02207
# Epoch 106/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.4156e-04 - val_loss: 0.0318
#
# Epoch 00106: val_loss did not improve from 0.02207
# Epoch 107/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.7244e-04 - val_loss: 0.0317
#
# Epoch 00107: val_loss did not improve from 0.02207
# Epoch 108/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.5801e-04 - val_loss: 0.0317
#
# Epoch 00108: val_loss did not improve from 0.02207
# Epoch 109/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.9744e-04 - val_loss: 0.0316
#
# Epoch 00109: val_loss did not improve from 0.02207
# Epoch 110/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.8969e-04 - val_loss: 0.0316
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 00110: val_loss did not improve from 0.02207
# Epoch 111/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.9248e-04 - val_loss: 0.0316
#
# Epoch 00111: val_loss did not improve from 0.02207
# Epoch 112/150
# 790/790 [==============================] - 34s 44ms/step - loss: 8.7855e-04 - val_loss: 0.0316
#
# Epoch 00112: val_loss did not improve from 0.02207
# Epoch 113/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.3876e-04 - val_loss: 0.0316
#
# Epoch 00113: val_loss did not improve from 0.02207
# Epoch 114/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.2849e-04 - val_loss: 0.0316
#
# Epoch 00114: val_loss did not improve from 0.02207
# Epoch 115/150
# 790/790 [==============================] - 33s 42ms/step - loss: 9.2412e-04 - val_loss: 0.0316
#
# Epoch 00115: val_loss did not improve from 0.02207
# Epoch 116/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1640e-04 - val_loss: 0.0316
#
# Epoch 00116: val_loss did not improve from 0.02207
# Epoch 117/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.5353e-04 - val_loss: 0.0317
#
# Epoch 00117: val_loss did not improve from 0.02207
# Epoch 118/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.2562e-04 - val_loss: 0.0317
#
# Epoch 00118: val_loss did not improve from 0.02207
# Epoch 119/150
# 790/790 [==============================] - 33s 42ms/step - loss: 9.0369e-04 - val_loss: 0.0317
#
# Epoch 00119: val_loss did not improve from 0.02207
# Epoch 120/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1300e-04 - val_loss: 0.0317
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 00120: val_loss did not improve from 0.02207
# Epoch 121/150
# 790/790 [==============================] - 34s 42ms/step - loss: 8.2485e-04 - val_loss: 0.0317
#
# Epoch 00121: val_loss did not improve from 0.02207
# Epoch 122/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.1707e-04 - val_loss: 0.0318
#
# Epoch 00122: val_loss did not improve from 0.02207
# Epoch 123/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6750e-04 - val_loss: 0.0317
#
# Epoch 00123: val_loss did not improve from 0.02207
# Epoch 124/150
# 790/790 [==============================] - 33s 42ms/step - loss: 6.8523e-04 - val_loss: 0.0317
#
# Epoch 00124: val_loss did not improve from 0.02207
# Epoch 125/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.2508e-04 - val_loss: 0.0317
#
# Epoch 00125: val_loss did not improve from 0.02207
# Epoch 126/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6690e-04 - val_loss: 0.0317
#
# Epoch 00126: val_loss did not improve from 0.02207
# Epoch 127/150
# 790/790 [==============================] - 34s 43ms/step - loss: 7.7546e-04 - val_loss: 0.0317
#
# Epoch 00127: val_loss did not improve from 0.02207
# Epoch 128/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6986e-04 - val_loss: 0.0317
#
# Epoch 00128: val_loss did not improve from 0.02207
# Epoch 129/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.8054e-04 - val_loss: 0.0317
#
# Epoch 00129: val_loss did not improve from 0.02207
# Epoch 130/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.2453e-04 - val_loss: 0.0317
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 00130: val_loss did not improve from 0.02207
# Epoch 131/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.5099e-04 - val_loss: 0.0317
#
# Epoch 00131: val_loss did not improve from 0.02207
# Epoch 132/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.7270e-04 - val_loss: 0.0317
#
# Epoch 00132: val_loss did not improve from 0.02207
# Epoch 133/150
# 790/790 [==============================] - 34s 42ms/step - loss: 7.9369e-04 - val_loss: 0.0317
#
# Epoch 00133: val_loss did not improve from 0.02207
# Epoch 134/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.5984e-04 - val_loss: 0.0317
#
# Epoch 00134: val_loss did not improve from 0.02207
# Epoch 135/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0818e-04 - val_loss: 0.0317
#
# Epoch 00135: val_loss did not improve from 0.02207
# Epoch 136/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.4650e-04 - val_loss: 0.0317
#
# Epoch 00136: val_loss did not improve from 0.02207
# Epoch 137/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.0796e-04 - val_loss: 0.0317
#
# Epoch 00137: val_loss did not improve from 0.02207
# Epoch 138/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.0589e-04 - val_loss: 0.0317
#
# Epoch 00138: val_loss did not improve from 0.02207
# Epoch 139/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.2761e-04 - val_loss: 0.0317
#
# Epoch 00139: val_loss did not improve from 0.02207
# Epoch 140/150
# 790/790 [==============================] - 34s 43ms/step - loss: 6.9199e-04 - val_loss: 0.0317
#
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 00140: val_loss did not improve from 0.02207
# Epoch 141/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.6135e-04 - val_loss: 0.0317
#
# Epoch 00141: val_loss did not improve from 0.02207
# Epoch 142/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.4274e-04 - val_loss: 0.0317
#
# Epoch 00142: val_loss did not improve from 0.02207
# Epoch 143/150
# 790/790 [==============================] - 33s 42ms/step - loss: 6.9849e-04 - val_loss: 0.0317
#
# Epoch 00143: val_loss did not improve from 0.02207
# Epoch 144/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.4905e-04 - val_loss: 0.0317
#
# Epoch 00144: val_loss did not improve from 0.02207
# Epoch 145/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.1855e-04 - val_loss: 0.0317
#
# Epoch 00145: val_loss did not improve from 0.02207
# Epoch 146/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.6332e-04 - val_loss: 0.0317
#
# Epoch 00146: val_loss did not improve from 0.02207
# Epoch 147/150
# 790/790 [==============================] - 33s 42ms/step - loss: 8.5296e-04 - val_loss: 0.0317
#
# Epoch 00147: val_loss did not improve from 0.02207
# Epoch 148/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.3405e-04 - val_loss: 0.0317
#
# Epoch 00148: val_loss did not improve from 0.02207
# Epoch 149/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.9626e-04 - val_loss: 0.0317
#
# Epoch 00149: val_loss did not improve from 0.02207
# Epoch 150/150
# 790/790 [==============================] - 33s 42ms/step - loss: 7.7779e-04 - val_loss: 0.0317
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
#
# Epoch 00150: val_loss did not improve from 0.02207

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
#predicting 246 values, using past 60 from the train data
inputs = data2.iloc[len(data2) - len(valid_set) - 60:,1:2].values
inputs = inputs.reshape(-inputs.shape[1],inputs.shape[1])
inputs  = sc_valid.transform(inputs)

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
closing_price = regressor.predict(X_test)

# invert scaling for forecast
inv_yhat = np.concatenate((closing_price,X_test[:,-1]), axis=1)
closing_price = sc_valid.inverse_transform(inv_yhat)
# Out:
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A4FD5BBAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
lstm_sma_rms=np.sqrt(np.mean(np.power((valid_set-closing_price),2)))
lstm_sma_rms
# Out:
# 410.45551321084025

# %%
#for plotting
train = data2[:850]
valid = data2[850:]
valid['Predictions'] = closing_price[:,0]
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

plt.legend(labels=['Training Price', 'Actual Price', 'Predicted Price'])
# Out:
# <ipython-input-161-00805dc86a6b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price[:,0]
